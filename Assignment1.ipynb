# %% [markdown]
# # Individual Assignment: Classifying Risk of Heart Attack
# ## Trimester Feb 2025
#
# In this assignment, you shall implement an L-layer standard neural network. We shall train the network to classify if a patient is in danger of an imminent heart attack. This is an individual Assignment contributing 10 marks for the course. It is divided into 2 parts.
# * Part A: Coding (60%)
#     * Implement an L-layered neural network from scratch with numpy library.
#     * Deadline: 20 July 2025 (Week 4, Sunday Midnight)
# * Part B: Theory (40%)
#     * This is a quiz on the implementation for this assignment, covering both theory and coding aspects. The quiz wil be conducted during lecture class.
#     * Date: 23 July 2025 (Week 5, Wed during class)
#     * Duration: 25 minutes
#
# ---
# **Instruction**:
#
# 1. Install **Anaconda** on your **local** machine and work on your assignment using `jupyter notebook`.
# 2. Write your **name** and **student ID** at the top part of `a1_mlp.py`.
# 3. Write your answer in the following designated areas as shown in the following. **Do not change** any non-designated areas.
#     ``` python
#     ### BEGIN CODE HERE ###
#     # ... Implement your code in this designated area only.
#     ### END CODE HERE ###
#     ```
#     <br>
# 4. In this assignment, you are expected to use only the `sklearn` and `numpy` packages to implement the standard neural network from scratch. Do **not** import any other package, module, function or class other than those that have already been imported at `a1_mlp.py`. Do **not** use `pytorch` or other deep learning framework to implement the tasks.
# 5. **Submission instruction** for Part A:
#    - **Rename** `a1_mlp.py` as "`<your id>_a1_mlp.py`" and submit it through WBLE. You do not need to submit this notebook file.

# %%
from importlib import reload

import a1_mlp
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ---
#
# ## Section 1 : Loading the Dataset
#
# Load the dataset into a dataframe. The dataset comprises the information for $M = 303$ patients. For each person, $F_x = 13$ input attributes are collected. The targeted variable is the column `heart_attack_risk` where:
#
# 1. `heart_attack_risk` = 0: no risk of heart attack
# 2. `heart_attack_risk` = 1: high risk of heart attack

# %%
df = pd.read_csv('dataset.csv')
df.sample(5)
# Out:
#      heart_attack_risk  age  gender  chest_pain_type  max_heart_rate  \
# 157                  1   41       1                2             168
# 37                   0   53       1                0              95
# 287                  1   66       0                2             152
# 109                  0   63       0                0             169
# 129                  0   67       1                0              71
#
#      resting_ecg  resting_bp  cholestrol  num_major_vessels  \
# 157            0         130         214                  0
# 37             1         123         282                  2
# 287            0         146         278                  1
# 109            1         108         269                  2
# 129            1         120         237                  0
#
#      fasting_bloodsugar  exercise_induced_angina  thal_rate  oldpeak  slope
# 157                   0                        0          2      2.0      1
# 37                    0                        1          3      2.0      1
# 287                   0                        0          2      0.0      1
# 109                   0                        1          2      1.8      1
# 129                   0                        0          2      1.0      1

# %% [markdown]
# <br>
#
# > **Task 1.1 (5 marks)** Implement the `a1_mlp.get_splits` function to get the training and validation splits. Here are the steps:
# >
# > 1. Split the columns into the input matrix (`X`) and targeted output (`y`). The input matrix has a shape of $(M, 13)$ and the targeted variable $(M, 1)$.
# > 2. Then, split the dataset (`X`, `y`) into training set (`X_train`, `y_train`) and validation set (`X_val`, `y_val`) using [sklearn.model_selection.train_test_split](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html). Enable shuffling and set the random state to 42. The user should be allowed to set the split size `test_size`.

# %%
reload(a1_mlp)
X_train, X_val, y_train, y_val = a1_mlp.get_splits(df, test_size=0.2)

print(f'{X_train.shape = }')
print(f'{y_train.shape = }')
print(f'{X_val.shape = }')
print(f'{y_val.shape = }')
# Out:
# X_train.shape = (242, 13)
# y_train.shape = (242, 1)
# X_val.shape = (61, 13)
# y_val.shape = (61, 1)

# %% [markdown]
# <br>
#
# > **Task 1.2 (5 marks)** Implement the `a1_mlp.standardize` function to standardize the input matrices `X_train` and `X_val` with the [StandardScaler](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html) based on the mean and variance of training set.

# %%
reload(a1_mlp)
X_train, X_val = a1_mlp.standardize(X_train, X_val)

print(f'{X_train.mean() = :f}')
print(f'{X_train.var()  = :f}')
print(f'{X_val.mean() = :f}')
print(f'{X_val.var()  = :f}')
# Out:
# X_train.mean() = 0.000000
# X_train.var()  = 1.000000
# X_val.mean() = -0.003846
# X_val.var()  = 1.051152

# %% [markdown]
# ---
#
# ## Section 2: Initialization, Forward Propagation and Cost Function
#
# For the rest of this assignment, you can test your code on a two-layered neural network with the following settings.

# %%
M_train, Fx = X_train.shape

layer_sizes = [Fx, 20, 1]
act_functions = [None, 'tanh', 'sigmoid']
lr = 0.5
num_iters = 100

# %% [markdown]
# ### Initialization Function
#
# > **Task 2.1 (12 marks)** Initialize the network parameters
# >
# > Implement the `a1_mlp.xavier_init` function to initialize the network parameters. The function creates and initializes the weights $\mathbf{W} = \{\mathrm{None}, \mathbf{W}^{[1]}, \cdots,  \mathbf{W}^{[L]}\}$ and biases $\mathbf{b}  = \{\mathrm{None}, \mathbf{b}^{[1]}, \cdots, \mathbf{b}^{[L]}\}$ for all $L$ layers.
# >
# > * Use **Xavier initialization** (use [np.random.normal](https://numpy.org/doc/2.1/reference/random/generated/numpy.random.normal.html)) to initialize the weight matrices $\mathbf{W}^{[1]}$ where:
# >  $$\mathbf{W}^{[l]}  \thicksim \mathcal{N}(0, \frac{2}{F^{[l-1]} + F^{[l]}})$$
# > where $\mathcal{N}(\mu,\sigma^2)$ is the normal distribution with mean $\mu$ and variance $\sigma^2$. For xavier initialization, the standard deviation $\sigma = \sqrt{\frac{2}{F^{[l-1]} + F^{[l]}}}$ <br>The shape of $\mathbf{W}^{[l]} = \mathbb{R}^{F^{[l-1]}\times F^{[l]}}$ where $F^{[l-1]}$ and$F^{[l]}$ are the number of features (units) in the previous layer $l - 1$ and current layer $l$, respectively.
# > * Use **zero initialization** (use `np.zeros`) for the biases $\mathbf{b}^{[1]}, \cdots, \mathbf{b}^{[L]}$ where $\mathbf{b}^{[l]} = \mathbb{R}^{F^{[l]}\times 1}$.

# %%
reload(a1_mlp)
weights, biases = a1_mlp.xavier_init(layer_sizes)

print('dtype of weights :', [Wi.dtype for Wi in weights[1:]])
print('Shape of weights :', [Wi.shape for Wi in weights[1:]])
print('Mean of Wi       :', [float(Wi.mean()) for Wi in weights[1:]])
print('Std of Wi        :', [float(Wi.std()) for Wi in weights[1:]])

print('\ndtype of biases  :', [bi.dtype for bi in biases[1:]])
print('Shape of biases  : ', [bi.shape for bi in biases[1:]])
print('Mean of bi       :', [float(bi.mean()) for bi in biases[1:]])
print('Std of bi        :', [float(bi.std()) for bi in biases[1:]])
# Out:
# dtype of weights : [dtype('float64'), dtype('float64')]
# Shape of weights : [(13, 20), (20, 1)]
# Mean of Wi       : [0.0018747445236994556, -0.10672795544374929]
# Std of Wi        : [0.23937357903724135, 0.3365762532114717]
#
# dtype of biases  : [dtype('float64'), dtype('float64')]
# Shape of biases  :  [(20, 1), (1, 1)]
# Mean of bi       : [0.0, 0.0]
# Std of bi        : [0.0, 0.0]

# %% [markdown]
# >  **Task 2.2 (10 marks)** Forward propagation through a linear layer
# >
# > Implement the `a1_mlp.forward_linear` function which performs forward propagation for layer $l$ of the network.
# >
# > ![image.png](data:image/png;base64,...)
# >
# > The function `forward_linear` computes the value of $\mathbf{A}^{[l]}$ through two phases.
# >
# > * The *summation phase* computes the following equations:
# >
# >     $$\mathbf{Z}^{[l]} = \mathbf{A}^{[l-1]}\mathbf{W}^{[l]} + \mathbf{b}^{[l]T}$$
# >
# >     where $\mathbf{A}^{[l-1]}$ (or `A_prev`) is the previous activations from layer $l-1$ and $\mathbf{A}^{[l]}$ (or `A`) is the current activations from layer $l$. Note that $\mathbf{A}^{[0]} = \mathbf{X}$
# >
# > * The *activation phase* transforms the weighted input $\mathbf{Z}^{[l]}$ using a non-linear function. The function allows user to choose one of the two activation functions:
# >
# >   * *sigmoid* activation:
# >
# >     $$\mathbf{A}^{[l]}(\mathbf{Z}^{[l]}) = \frac{1}{1+e^{-\mathbf{Z}^{[l]}}}$$
# >
# >   * *tanh* activation:
# >
# >     $$\mathbf{A}^{[l]}(\mathbf{Z}^{[l]}) = \frac{e^{\mathbf{Z}^{[l]}}-e^{-\mathbf{Z}^{[l]}}}{e^{\mathbf{Z}^{[l]}}+e^{-\mathbf{Z}^{[l]}}}$$
# >
# > The function also returns a cache value that stores all the tensors in the forward propagation that is required for backpropagation later.
# >
# > $$\mathrm{cache}^{[l]} = (\mathbf{W}^{[l]}, \mathbf{A}^{[l-1]}, \mathbf{A}^{[l]})$$

# %%
reload(a1_mlp)

A1, cache1 = a1_mlp.forward_linear(X_train, weights[1], biases[1], "tanh")
A2, cache2 = a1_mlp.forward_linear(A1, weights[2], biases[2], "sigmoid")

print(f'Layer 1: input shape = {X_train.shape}, output shape = {A1.shape}')
print(f'Layer 2: input shape = {A1.shape}, output shape = {A2.shape}')

print(f'\nA1:\n{A1[:3,:5]}')
print(f'\nA2:\n{A2[:3,:5]}')
# Out:
# Layer 1: input shape = (242, 13), output shape = (242, 20)
# Layer 2: input shape = (242, 20), output shape = (242, 1)
#
# A1:
# [[ 0.51847139  0.36277494  0.83422331 -0.46526295 -0.02792944]
#  [-0.79793795  0.17945402 -0.19968765  0.77735434  0.67202721]
#  [-0.75561479  0.87919656  0.17374779 -0.77535987  0.31208457]]
#
# A2:
# [[0.19726208]
#  [0.74819208]
#  [0.25122037]]

# %% [markdown]
# > **Task 2.3 (12 marks)** Forward propagation for the standard neural network
# >
# > Complete the `a1_mlp.forward` function to perform forward propagation algorithm through an $L$-layered neural network.
# > * The model is parameterized by `weights` and `biases`.
# > * Given an input signal $\mathbf{X}$, forward propagation computes the predicted output $\hat{\mathbf{Y}}$ (or equivalently $\mathbf{A}^{[L]}$). To do that, use a *for* to perform forward propagation (`forward_linear`) through all layers $i = 1, \cdots, L$.
# > * Clip the output of the network $\mathbf{A}^{[L]}$ so that it lies in the range [1e-5, 1-1e-5] for numerical stability when computing the cost later.
# > * Save the cache of each layer `cache[i]` into a list called `caches`. Note that for the input layer, `caches[0]` is set to `None`.
# >
# > ![image.png](data:image/png;base64,...)

# %%
reload(a1_mlp)

y_hat, caches = a1_mlp.forward(X_train, weights, biases, act_functions)

print(f'Predicted value for first 5 samples):\n{y_hat[:5].T}')
print(f'\n{y_hat.shape = }')
print(f'{len(caches)   = }')
# Out:
# Predicted value for first 5 samples):
# [[0.19726208 0.74819208 0.25122037 0.37627309 0.73408172]]
#
# y_hat.shape = (242, 1)
# len(caches)   = 3

# %% [markdown]
# > **Task 2.4 (5 marks)** Binary cross entropy cost function
# >
# > Implement the `a1_mlp.compute_cost` function to compute the binary cost entropy by comparing the predicted value $\hat{\mathbf{y}}$ and the actual label $\mathbf{y}$.
# >
# > \begin{eqnarray*}
# J(\mathbf{W}, \mathbf{b}) & = & \frac{1}{M} \sum_{i = 1}^{M} - y^{(i)}\log \hat{y}^{(i)} - (1-y^{(i)})\log (1- \hat{y}^{(i)}) \\
#              & = & \textrm{mean}(-\mathbf{y}*\log(\hat{\mathbf{y}}) - (1-\mathbf{y})*\log(1-\hat{\mathbf{y}}))
# \end{eqnarray*}
# >
# > where $*$ is the element-wise operation product operation.

# %%
reload(a1_mlp)

cost = a1_mlp.compute_cost(y_hat, y_train)
print(f'{cost = :.4f}')
# Out:
# cost = 0.6522

# %% [markdown]
# ---
# ## Section 3: Backpropagation

# %% [markdown]
# > **Task 3.1 (5 marks)** Backpropagation for the cost layer
# >
# > Implement the `a1_mlp.backprop_cost_layer` function to backprop through the cost function as shown in the figure below.
# >
# > ![image.png](data:image/png;base64,...)
# >
# > Backpropagating through the cost layer gives us the gradient at the output of the last fully connected layer which is given by:
# >
# > $$\frac{\partial J}{\partial \hat{\mathbf{y}}} = \frac{1}{M} (\frac{1 - \mathbf{y}}{1 - \hat{\mathbf{y}}} - \frac{\mathbf{y}}{\hat{\mathbf{y}}})$$
# >
# > where $M$ is the number of samples, $\mathbf{y}$ is the actual label and $\hat{\mathbf{y}}$ is the predicted value.

# %%
reload(a1_mlp)

dAL = a1_mlp.backprop_cost_layer(y_hat, y_train)
print('dAL:\n', dAL[:5])
assert dAL.shape == y_hat.shape
# Out:
# dAL:
#  [[ 0.00514767]
#  [-0.00552296]
#  [-0.01644863]
#  [ 0.00662507]
#  [-0.00562912]]

# %% [markdown]
# > **Task 3.2 (16 marks)** Backpropagation for the linear layer
# >
# > Complete the function `a1_mlp.backprop_linear_layer` which performs the backpropagation through *one* fully connected (FC) layer.
# >
# > The inputs to the model are:
# > * $\mathrm{cache}^{[l]} = (\mathbf{W}^{[l]}, \mathbf{A}^{[l-1]}, \mathbf{A}^{[l]})$ was generated when performing forward propagation (`forward_linear`) for all layers $l = 1, \cdots, L$ in `forward`) earlier. `cache[l]` stores the tensors required when backpropagating through layer $l$.
# > * $\frac{\partial J}{\partial \mathbf{A}^{[l]}}$ is the upstream gradient of layer $l$ and is computed by `backprop_linear_layer` on layer $l+1$.
# >
# > ![image.png](data:image/png;base64,...)
# >
# > To perform backpropagation through layer $[l]$, it first backprop through the *activation* function followed by the *summation* function:
# >
# > 1. **Backprop through activation phase**. The input is the upstream gradient $\frac{\partial J}{\partial \mathbf{A}^{[l]}}$. The output $\frac{\partial J}{\partial \mathbf{Z}^{[l]}}$ is computed as follows:
# >   * For *sigmoid* activation:
# >     $$\frac{\partial J}{\partial \mathbf{Z}^{[l]}} = \frac{\partial J}{\partial \mathbf{A}^{[l]}}* \mathbf{A}^{[l]}*(1-\mathbf{A}^{[l]})$$
# >
# >    * For *tanh* activation:
#     $$\frac{\partial J}{\partial \mathbf{Z}^{[l]}} = \frac{\partial J}{\partial \mathbf{A}^{[l]}}* \big(1 - (\mathbf{A}^{[l]})^2\big)$$
# >
# >   where $*$ is performing *element-wise* multiplication. <br> <br>
# >
# > 2. **Backprop through summation phase**. The input is the upstream gradient $\frac{\partial J}{\partial \mathbf{Z}^{[l]}}$. The outputs $\frac{\partial J}{\partial \mathbf{W}^{[l]}}$, $\frac{\partial J}{\partial \mathbf{b}^{[l]}}$ and $\frac{\partial J}{\partial \mathbf{A}^{[l-1]}}$ are computed as follows:
# >
# >     $$ \frac{\partial J}{\partial \mathbf{W}^{[l]}} =  \mathbf{A}^{[l-1]T} \frac{\partial J}{\partial \mathbf{Z}^{[l]}} $$
# >
# >     $$ \frac{\partial J}{\partial \mathbf{b}^{[l]}} =  (\mathbf{1}^T \frac{\partial J}{\partial \mathbf{Z}^{[l]}})^T$$
# >
# >     $$ \frac{\partial J}{\partial \mathbf{A}^{[l-1]}} = \frac{\partial J}{\partial \mathbf{Z}^{[l]}}\mathbf{W}^{[l]T}$$
# >
# > Notes: $\frac{\partial J}{\partial \mathbf{b}^{[l]}}$ can also be implemented by summing the rows of $\frac{\partial J}{\partial \mathbf{Z}^{[l]}}$ and then transposing it to get the column vector.

# %%
reload(a1_mlp)

dA1, dW2, db2 = a1_mlp.backprop_linear_layer(dAL, caches[2], "sigmoid")
print('Backprop for sigmoid activation:')
print(f'dA1: Shape = {dA1.shape}: {dA1[0, :4]}')
print(f'dW2: Shape = {dW2.shape}: {dW2[:4].T}')
print(f'db2: Shape = {db2.shape}: {db2}')

dA1, dW2, db2 = a1_mlp.backprop_linear_layer(dAL, caches[2], "tanh")
print('\nBackprop for tanh activation:')
print(f'dA1: Shape = {dA1.shape}: {dA1[0, :4]}')
print(f'dW2: Shape = {dW2.shape}: {dW2[:4].T}')
print(f'db2: Shape = {db2.shape}: {db2}')
# Out:
# Backprop for sigmoid activation:
# dA1: Shape = (242, 20): [-9.63530302e-07 -6.18757135e-08 -3.36924871e-06 -1.06483557e-06]
# dW2: Shape = (20, 1): [[ 0.00038048 -0.00017388 -0.00023069  0.0001625 ]]
# db2: Shape = (1, 1): [[-0.00018544]]
#
# Backprop for tanh activation:
# dA1: Shape = (242, 20): [-5.84804901e-06 -3.75548340e-07 -2.04493118e-05 -6.46291099e-06]
# dW2: Shape = (20, 1): [[ 0.00118477 -0.00053994 -0.00081219  0.00062073]]
# db2: Shape = (1, 1): [[-0.00073544]]

# %% [markdown]
# > **Task 3.3 (12 marks)**: Backpropagation for the standard neural network
# >
# > Complete the function `a1_mlp.backprop` to implement the backpropagation for the whole standard neural network. The backpropagation algorithm computes the gradient of the cost w.r.t. all model parameters, i.e., $\frac{\partial J}{\mathbf{W}^{[1]}}$, $\frac{\partial J}{\mathbf{b}^{[1]}}$, ..., $\frac{\partial J}{\mathbf{W}^{[L]}}$, $\frac{\partial J}{\mathbf{b}^{[L]}}$.
# >
# > ![image.png](data:image/png;base64,...)
# >
# > The backpropagation algorithm first backprops through the cost function. Then, it backprops through the fully connected layers starting from the *last* linear layer back to layer 1.
# >
# > * To backprop through the loss function, call the `backprop_cost_layer`
# $$\frac{\partial J}{\partial \mathbf{A}^{[L]}} = \mathrm{backprop\_cost\_layer} (\mathbf{y}, \hat{\mathbf{y}})$$
# > * To backprop through the fully connected layers, use a `for` loop and call `backprop_linear_layer` to process each layer iteratively starting from layer $L$ back to layer 1.
# >
# > $$\frac{\partial J}{\partial \mathbf{A}^{[l-1]}} = \mathrm{backprop\_linear\_layer}(\frac{\partial J}{\partial \mathbf{A}^{[l]}}, \mathrm{cache}^{[l]}, \mathbf{A}^{[l]})$$

# %%
reload(a1_mlp)
weights_grad, biases_grad = a1_mlp.backprop(y_hat, y_train, act_functions, caches)

print('Shape of the weights   =', [w if w is None else w.shape for w in weights_grad])
print('Shape of the biases    =', [b if b is None else b.shape for b in biases])

print('\nweights[1] (first 3 rows):')
print(weights[1][:5,:3])

print('\nbiases[1] (first 3 rows):')
print(biases[1][:3])

print('\nweights[2] (first 3 rows):')
print(weights[2][:3])

print('\nbiases[2]:')
print(biases[2])
# Out:
# Shape of the weights   = [None, (13, 20), (20, 1)]
# Shape of the biases    = [None, (20, 1), (1, 1)]
#
# weights[1] (first 3 rows):
# [[ 0.12228257 -0.03403832  0.1594499 ]
#  [ 0.36081778 -0.05558228  0.01662429]
#  [ 0.1817979   0.04218795 -0.02847064]
#  [-0.11796454 -0.04570608 -0.27236084]
#  [-0.05407948  0.08791504  0.36383236]]
#
# biases[1] (first 3 rows):
# [[0.]
#  [0.]
#  [0.]]
#
# weights[2] (first 3 rows):
# [[-0.28605695]
#  [-0.01836992]
#  [-1.00027682]]
#
# biases[2]:
# [[0.]]

# %% [markdown]
# ---
# ## Section 4: Training and Evaluation
#
# > **Task 4.1 (10 marks)** Batch Gradient Descent algorithm
# >
# > Implement the function `a1_mlp.train` which implements the gradient descent algorithm to train the network given a training set.
# >
# > 1. Initialize parameters with Xavier initialization
# > 2. Repeat for num_iters times:
# >     1. Forward propagation
# >     2. Compute cost
# >     3. Backpropagation
# >     4. Update parameters as follows:
# >         $$ \mathbf{W}^{[l]} = \mathbf{W}^{[l]} - \alpha \frac{\partial J}{\partial \mathbf{W}^{[l]}} \quad \forall l$$
# >         $$ \mathbf{b}^{[l]} = \mathbf{b}^{[l]} - \alpha \frac{\partial J}{\partial \mathbf{b}^{[l]}} \quad \forall l$$
# >
# > where $\alpha$ is the learning rate. The function returns the network parameters (`weights` and `biases`) and the training cost plot (`history`).

# %%
reload(a1_mlp)

weights, biases, history = a1_mlp.train (X_train, y_train, layer_sizes, act_functions, 
                                  lr=lr, num_iters=num_iters)
# Out:
# Iter   1 : training cost = 0.6522
# Iter   5 : training cost = 0.6514
# Iter  10 : training cost = 0.6505
# Iter  15 : training cost = 0.6496
# Iter  20 : training cost = 0.6487
# Iter  25 : training cost = 0.6478
# Iter  30 : training cost = 0.6469
# Iter  35 : training cost = 0.6460
# Iter  40 : training cost = 0.6451
# Iter  45 : training cost = 0.6442
# Iter  50 : training cost = 0.6434
# Iter  55 : training cost = 0.6425
# Iter  60 : training cost = 0.6416
# Iter  65 : training cost = 0.6408
# Iter  70 : training cost = 0.6399
# Iter  75 : training cost = 0.6391
# Iter  80 : training cost = 0.6383
# Iter  85 : training cost = 0.6374
# Iter  90 : training cost = 0.6366
# Iter  95 : training cost = 0.6358
# Iter 100 : training cost = 0.6349
# Iter 105 : training cost = 0.6341
# Iter 110 : training cost = 0.6333
# Iter 115 : training cost = 0.6325
# Iter 120 : training cost = 0.6317
# Iter 125 : training cost = 0.6309
# Iter 130 : training cost = 0.6301
# Iter 135 : training cost = 0.6294
# Iter 140 : training cost = 0.6286
# Iter 145 : training cost = 0.6278
# Iter 150 : training cost = 0.6270
# Iter 155 : training cost = 0.6263
# Iter 160 : training cost = 0.6255
# Iter 165 : training cost = 0.6248
# Iter 170 : training cost = 0.6240
# Iter 175 : training cost = 0.6233
# Iter 180 : training cost = 0.6225
# Iter 185 : training cost = 0.6218
# Iter 190 : training cost = 0.6210
# Iter 195 : training cost = 0.6203
# Iter 200 : training cost = 0.6196
# Iter 205 : training cost = 0.6189
# Iter 210 : training cost = 0.6182
# Iter 215 : training cost = 0.6174
# Iter 220 : training cost = 0.6167
# Iter 225 : training cost = 0.6160
# Iter 230 : training cost = 0.6153
# Iter 235 : training cost = 0.6146
# Iter 240 : training cost = 0.6139
# Iter 245 : training cost = 0.6133
# Iter 250 : training cost = 0.6126
# Iter 255 : training cost = 0.6119
# Iter 260 : training cost = 0.6112
# Iter 265 : training cost = 0.6106
# Iter 270 : training cost = 0.6099
# Iter 275 : training cost = 0.6092
# Iter 280 : training cost = 0.6086
# Iter 285 : training cost = 0.6079
# Iter 290 : training cost = 0.6073
# Iter 295 : training cost = 0.6066
# Iter 300 : training cost = 0.6060
# Iter 305 : training cost = 0.6053
# Iter 310 : training cost = 0.6047
# Iter 315 : training cost = 0.6041
# Iter 320 : training cost = 0.6034
# Iter 325 : training cost = 0.6028
# Iter 330 : training cost = 0.6022
# Iter 335 : training cost = 0.6016
# Iter 340 : training cost = 0.6009
# Iter 345 : training cost = 0.6003
# Iter 350 : training cost = 0.5997
# Iter 355 : training cost = 0.5991
# Iter 360 : training cost = 0.5985
# Iter 365 : training cost = 0.5979
# Iter 370 : training cost = 0.5973
# Iter 375 : training cost = 0.5967
# Iter 380 : training cost = 0.5961
# Iter 385 : training cost = 0.5956
# Iter 390 : training cost = 0.5950
# Iter 395 : training cost = 0.5944
# Iter 400 : training cost = 0.5938
# Iter 405 : training cost = 0.5932
# Iter 410 : training cost = 0.5927
# Iter 415 : training cost = 0.5921
# Iter 420 : training cost = 0.5915
# Iter 425 : training cost = 0.5910
# Iter 430 : training cost = 0.5904
# Iter 435 : training cost = 0.5899
# Iter 440 : training cost = 0.5893
# Iter 445 : training cost = 0.5888
# Iter 450 : training cost = 0.5882
# Iter 455 : training cost = 0.5877
# Iter 460 : training cost = 0.5871
# Iter 465 : training cost = 0.5866
# Iter 470 : training cost = 0.5861
# Iter 475 : training cost = 0.5855
# Iter 480 : training cost = 0.5850
# Iter 485 : training cost = 0.5845
# Iter 490 : training cost = 0.5840
# Iter 495 : training cost = 0.5834
# Iter 500 : training cost = 0.5829
# Iter 505 : training cost = 0.5824
# Iter 510 : training cost = 0.5819
# Iter 515 : training cost = 0.5814
# Iter 520 : training cost = 0.5809
# Iter 525 : training cost = 0.5804
# Iter 530 : training cost = 0.5799
# Iter 535 : training cost = 0.5794
# Iter 540 : training cost = 0.5789
# Iter 545 : training cost = 0.5784
# Iter 550 : training cost = 0.5779
# Iter 555 : training cost = 0.5774
# Iter 560 : training cost = 0.5769
# Iter 565 : training cost = 0.5764
# Iter 570 : training cost = 0.5760
# Iter 575 : training cost = 0.5755
# Iter 580 : training cost = 0.5750
# Iter 585 : training cost = 0.5745
# Iter 590 : training cost = 0.5741
# Iter 595 : training cost = 0.5736
# Iter 600 : training cost = 0.5731
# Iter 605 : training cost = 0.5727
# Iter 610 : training cost = 0.5722
# Iter 615 : training cost = 0.5717
# Iter 620 : training cost = 0.5713
# Iter 625 : training cost = 0.5708
# Iter 630 : training cost = 0.5704
# Iter 635 : training cost = 0.5699
# Iter 640 : training cost = 0.5695
# Iter 645 : training cost = 0.5690
# Iter 650 : training cost = 0.5686
# Iter 655 : training cost = 0.5681
# Iter 660 : training cost = 0.5677
# Iter 665 : training cost = 0.5673
# Iter 670 : training cost = 0.5668
# Iter 675 : training cost = 0.5664
# Iter 680 : training cost = 0.5660
# Iter 685 : training cost = 0.5655
# Iter 690 : training cost = 0.5651
# Iter 695 : training cost = 0.5647
# Iter 700 : training cost = 0.5642
# Iter 705 : training cost = 0.5638
# Iter 710 : training cost = 0.5634
# Iter 715 : training cost = 0.5630
# Iter 720 : training cost = 0.5626
# Iter 725 : training cost = 0.5622
# Iter 730 : training cost = 0.5617
# Iter 735 : training cost = 0.5613
# Iter 740 : training cost = 0.5609
# Iter 745 : training cost = 0.5605
# Iter 750 : training cost = 0.5601
# Iter 755 : training cost = 0.5597
# Iter 760 : training cost = 0.5593
# Iter 765 : training cost = 0.5589
# Iter 770 : training cost = 0.5585
# Iter 775 : training cost = 0.5581
# Iter 780 : training cost = 0.5577
# Iter 785 : training cost = 0.5573
# Iter 790 : training cost = 0.5569
# Iter 795 : training cost = 0.5566
# Iter 800 : training cost = 0.5562
# Iter 805 : training cost = 0.5558
# Iter 810 : training cost = 0.5554
# Iter 815 : training cost = 0.5550
# Iter 820 : training cost = 0.5546
# Iter 825 : training cost = 0.5543
# Iter 830 : training cost = 0.5539
# Iter 835 : training cost = 0.5535
# Iter 840 : training cost = 0.5531
# Iter 845 : training cost = 0.5528
# Iter 850 : training cost = 0.5524
# Iter 855 : training cost = 0.5520
# Iter 860 : training cost = 0.5517
# Iter 865 : training cost = 0.5513
# Iter 870 : training cost = 0.5509
# Iter 875 : training cost = 0.5506
# Iter 880 : training cost = 0.5502
# Iter 885 : training cost = 0.5499
# Iter 890 : training cost = 0.5495
# Iter 895 : training cost = 0.5491
# Iter 900 : training cost = 0.5488
# Iter 905 : training cost = 0.5484
# Iter 910 : training cost = 0.5481
# Iter 915 : training cost = 0.5477
# Iter 920 : training cost = 0.5474
# Iter 925 : training cost = 0.5470
# Iter 930 : training cost = 0.5467
# Iter 935 : training cost = 0.5463
# Iter 940 : training cost = 0.5460
# Iter 945 : training cost = 0.5457
# Iter 950 : training cost = 0.5453
# Iter 955 : training cost = 0.5450
# Iter 960 : training cost = 0.5447
# Iter 965 : training cost = 0.5443
# Iter 970 : training cost = 0.5440
# Iter 975 : training cost = 0.5437
# Iter 980 : training cost = 0.5433
# Iter 985 : training cost = 0.5430
# Iter 990 : training cost = 0.5427
# Iter 995 : training cost = 0.5423
# Iter 1000 : training cost = 0.5420
# Iter 1005 : training cost = 0.5417
# Iter 1010 : training cost = 0.5414
# Iter 1015 : training cost = 0.5410
# Iter 1020 : training cost = 0.5407
# Iter 1025 : training cost = 0.5404
# Iter 1030 : training cost = 0.5401
# Iter 1035 : training cost = 0.5398
# Iter 1040 : training cost = 0.5395
# Iter 1045 : training cost = 0.5391
# Iter 1050 : training cost = 0.5388
# Iter 1055 : training cost = 0.5385
# Iter 1060 : training cost = 0.5382
# Iter 1065 : training cost = 0.5379
# Iter 1070 : training cost = 0.5376
# Iter 1075 : training cost = 0.5373
# Iter 1080 : training cost = 0.5370
# Iter 1085 : training cost = 0.5367
# Iter 1090 : training cost = 0.5364
# Iter 1095 : training cost = 0.5361
# Iter 1100 : training cost = 0.5358
# Iter 1105 : training cost = 0.5355
# Iter 1110 : training cost = 0.5352
# Iter 1115 : training cost = 0.5349
# Iter 1120 : training cost = 0.5346
# Iter 1125 : training cost = 0.5343
# Iter 1130 : training cost = 0.5340
# Iter 1135 : training cost = 0.5337
# Iter 1140 : training cost = 0.5334
# Iter 1145 : training cost = 0.5331
# Iter 1150 : training cost = 0.5328
# Iter 1155 : training cost = 0.5325
# Iter 1160 : training cost = 0.5322
# Iter 1165 : training cost = 0.5320
# Iter 1170 : training cost = 0.5317
# Iter 1175 : training cost = 0.5314
# Iter 1180 : training cost = 0.5311
# Iter 1185 : training cost = 0.5308
# Iter 1190 : training cost = 0.5305
# Iter 1195 : training cost = 0.5303
# Iter 1200 : training cost = 0.5300
# Iter 1205 : training cost = 0.5297
# Iter 1210 : training cost = 0.5294
# Iter 1215 : training cost = 0.5292
# Iter 1220 : training cost = 0.5289
# Iter 1225 : training cost = 0.5286
# Iter 1230 : training cost = 0.5283
# Iter 1235 : training cost = 0.5281
# Iter 1240 : training cost = 0.5278
# Iter 1245 : training cost = 0.5275
# Iter 1250 : training cost = 0.5273
# Iter 1255 : training cost = 0.5270
# Iter 1260 : training cost = 0.5267
# Iter 1265 : training cost = 0.5265
# Iter 1270 : training cost = 0.5262
# Iter 1275 : training cost = 0.5259
# Iter 1280 : training cost = 0.5257
# Iter 1285 : training cost = 0.5254
# Iter 1290 : training cost = 0.5251
# Iter 1295 : training cost = 0.5249
# Iter 1300 : training cost = 0.5246
# Iter 1305 : training cost = 0.5244
# Iter 1310 : training cost = 0.5241
# Iter 1315 : training cost = 0.5239
# Iter 1320 : training cost = 0.5236
# Iter 1325 : training cost = 0.5233
# Iter 1330 : training cost = 0.5231
# Iter 1335 : training cost = 0.5228
# Iter 1340 : training cost = 0.5226
# Iter 1345 : training cost = 0.5223
# Iter 1350 : training cost = 0.5221
# Iter 1355 : training cost = 0.5218
# Iter 1360 : training cost = 0.5216
# Iter 1365 : training cost = 0.5213
# Iter 1370 : training cost = 0.5211
# Iter 1375 : training cost = 0.5208
# Iter 1380 : training cost = 0.5206
# Iter 1385 : training cost = 0.5204
# Iter 1390 : training cost = 0.5201
# Iter 1395 : training cost = 0.5199
# Iter 1400 : training cost = 0.5196
# Iter 1405 : training cost = 0.5194
# Iter 1410 : training cost = 0.5191
# Iter 1415 : training cost = 0.5189
# Iter 1420 : training cost = 0.5187
# Iter 1425 : training cost = 0.5184
# Iter 1430 : training cost = 0.5182
# Iter 1435 : training cost = 0.5180
# Iter 1440 : training cost = 0.5177
# Iter 1445 : training cost = 0.5175
# Iter 1450 : training cost = 0.5173
# Iter 1455 : training cost = 0.5170
# Iter 1460 : training cost = 0.5168
# Iter 1465 : training cost = 0.5166
# Iter 1470 : training cost = 0.5163
# Iter 1475 : training cost = 0.5161
# Iter 1480 : training cost = 0.5159
# Iter 1485 : training cost = 0.5156
# Iter 1490 : training cost = 0.5154
# Iter 1495 : training cost = 0.5152
# Iter 1500 : training cost = 0.5150
# Iter 1505 : training cost = 0.5147
# Iter 1510 : training cost = 0.5145
# Iter 1515 : training cost = 0.5143
# Iter 1520 : training cost = 0.5141
# Iter 1525 : training cost = 0.5138
# Iter 1530 : training cost = 0.5136
# Iter 1535 : training cost = 0.5134
# Iter 1540 : training cost = 0.5132
# Iter 1545 : training cost = 0.5129
# Iter 1550 : training cost = 0.5127
# Iter 1555 : training cost = 0.5125
# Iter 1560 : training cost = 0.5123
# Iter 1565 : training cost = 0.5121
# Iter 1570 : training cost = 0.5119
# Iter 1575 : training cost = 0.5116
# Iter 1580 : training cost = 0.5114
# Iter 1585 : training cost = 0.5112
# Iter 1590 : training cost = 0.5110
# Iter 1595 : training cost = 0.5108
# Iter 1600 : training cost = 0.5106
# Iter 1605 : training cost = 0.5104
# Iter 1610 : training cost = 0.5101
# Iter 1615 : training cost = 0.5099
# Iter 1620 : training cost = 0.5097
# Iter 1625 : training cost = 0.5095
# Iter 1630 : training cost = 0.5093
# Iter 1635 : training cost = 0.5091
# Iter 1640 : training cost = 0.5089
# Iter 1645 : training cost = 0.5087
# Iter 1650 : training cost = 0.5085
# Iter 1655 : training cost = 0.5083
# Iter 1660 : training cost = 0.5081
# Iter 1665 : training cost = 0.5079
# Iter 1670 : training cost = 0.5077
# Iter 1675 : training cost = 0.5075
# Iter 1680 : training cost = 0.5073
# Iter 1685 : training cost = 0.5071
# Iter 1690 : training cost = 0.5069
# Iter 1695 : training cost = 0.5067
# Iter 1700 : training cost = 0.5065
# Iter 1705 : training cost = 0.5063
# Iter 1710 : training cost = 0.5061
# Iter 1715 : training cost = 0.5059
# Iter 1720 : training cost = 0.5057
# Iter 1725 : training cost = 0.5055
# Iter 1730 : training cost = 0.5053
# Iter 1735 : training cost = 0.5051
# Iter 1740 : training cost = 0.5049
# Iter 1745 : training cost = 0.5047
# Iter 1750 : training cost = 0.5045
# Iter 1755 : training cost = 0.5043
# Iter 1760 : training cost = 0.5041
# Iter 1765 : training cost = 0.5039
# Iter 1770 : training cost = 0.5037
# Iter 1775 : training cost = 0.5035
# Iter 1780 : training cost = 0.5033
# Iter 1785 : training cost = 0.5031
# Iter 1790 : training cost = 0.5029
# Iter 1795 : training cost = 0.5028
# Iter 1800 : training cost = 0.5026
# Iter 1805 : training cost = 0.5024
# Iter 1810 : training cost = 0.5022
# Iter 1815 : training cost = 0.5020
# Iter 1820 : training cost = 0.5018
# Iter 1825 : training cost = 0.5016
# Iter 1830 : training cost = 0.5014
# Iter 1835 : training cost = 0.5013
# Iter 1840 : training cost = 0.5011
# Iter 1845 : training cost = 0.5009
# Iter 1850 : training cost = 0.5007
# Iter 1855 : training cost = 0.5005
# Iter 1860 : training cost = 0.5003
# Iter 1865 : training cost = 0.5002
# Iter 1870 : training cost = 0.5000
# Iter 1875 : training cost = 0.4998
# Iter 1880 : training cost = 0.4996
# Iter 1885 : training cost = 0.4994
# Iter 1890 : training cost = 0.4993
# Iter 1895 : training cost = 0.4991
# Iter 1900 : training cost = 0.4989
# Iter 1905 : training cost = 0.4987
# Iter 1910 : training cost = 0.4985
# Iter 1915 : training cost = 0.4984
# Iter 1920 : training cost = 0.4982
# Iter 1925 : training cost = 0.4980
# Iter 1930 : training cost = 0.4978
# Iter 1935 : training cost = 0.4977
# Iter 1940 : training cost = 0.4975
# Iter 1945 : training cost = 0.4973
# Iter 1950 : training cost = 0.4971
# Iter 1955 : training cost = 0.4970
# Iter 1960 : training cost = 0.4968
# Iter 1965 : training cost = 0.4966
# Iter 1970 : training cost = 0.4964
# Iter 1975 : training cost = 0.4963
# Iter 1980 : training cost = 0.4961
# Iter 1985 : training cost = 0.4959
# Iter 1990 : training cost = 0.4958
# Iter 1995 : training cost = 0.4956
# Iter 2000 : training cost = 0.4954
# Iter 2005 : training cost = 0.4952
# Iter 2010 : training cost = 0.4951
# Iter 2015 : training cost = 0.4949
# Iter 2020 : training cost = 0.4947
# Iter 2025 : training cost = 0.4946
# Iter 2030 : training cost = 0.4944
# Iter 2035 : training cost = 0.4942
# Iter 2040 : training cost = 0.4941
# Iter 2045 : training cost = 0.4939
# Iter 2050 : training cost = 0.4937
# Iter 2055 : training cost = 0.4936
# Iter 2060 : training cost = 0.4934
# Iter 2065 : training cost = 0.4933
# Iter 2070 : training cost = 0.4931
# Iter 2075 : training cost = 0.4929
# Iter 2080 : training cost = 0.4928
# Iter 2085 : training cost = 0.4926
# Iter 2090 : training cost = 0.4924
# Iter 2095 : training cost = 0.4923
# Iter 2100 : training cost = 0.4921
# Iter 2105 : training cost = 0.4920
# Iter 2110 : training cost = 0.4918
# Iter 2115 : training cost = 0.4916
# Iter 2120 : training cost = 0.4915
# Iter 2125 : training cost = 0.4913
# Iter 2130 : training cost = 0.4912
# Iter 2135 : training cost = 0.4910
# Iter 2140 : training cost = 0.4908
# Iter 2145 : training cost = 0.4907
# Iter 2150 : training cost = 0.4905
# Iter 2155 : training cost = 0.4904
# Iter 2160 : training cost = 0.4902
# Iter 2165 : training cost = 0.4901
# Iter 2170 : training cost = 0.4899
# Iter 2175 : training cost = 0.4897
# Iter 2180 : training cost = 0.4896
# Iter 2185 : training cost = 0.4894
# Iter 2190 : training cost = 0.4893
# Iter 2195 : training cost = 0.4891
# Iter 2200 : training cost = 0.4890
# Iter 2205 : training cost = 0.4888
# Iter 2210 : training cost = 0.4887
# Iter 2215 : training cost = 0.4885
# Iter 2220 : training cost = 0.4884
# Iter 2225 : training cost = 0.4882
# Iter 2230 : training cost = 0.4881
# Iter 2235 : training cost = 0.4879
# Iter 2240 : training cost = 0.4878
# Iter 2245 : training cost = 0.4876
# Iter 2250 : training cost = 0.4875
# Iter 2255 : training cost = 0.4873
# Iter 2260 : training cost = 0.4872
# Iter 2265 : training cost = 0.4870
# Iter 2270 : training cost = 0.4869
# Iter 2275 : training cost = 0.4867
# Iter 2280 : training cost = 0.4866
# Iter 2285 : training cost = 0.4864
# Iter 2290 : training cost = 0.4863
# Iter 2295 : training cost = 0.4861
# Iter 2300 : training cost = 0.4860
# Iter 2305 : training cost = 0.4858
# Iter 2310 : training cost = 0.4857
# Iter 2315 : training cost = 0.4855
# Iter 2320 : training cost = 0.4854
# Iter 2325 : training cost = 0.4853
# Iter 2330 : training cost = 0.4851
# Iter 2335 : training cost = 0.4850
# Iter 2340 : training cost = 0.4848
# Iter 2345 : training cost = 0.4847
# Iter 2350 : training cost = 0.4845
# Iter 2355 : training cost = 0.4844
# Iter 2360 : training cost = 0.4843
# Iter 2365 : training cost = 0.4841
# Iter 2370 : training cost = 0.4840
# Iter 2375 : training cost = 0.4838
# Iter 2380 : training cost = 0.4837
# Iter 2385 : training cost = 0.4835
# Iter 2390 : training cost = 0.4834
# Iter 2395 : training cost = 0.4833
# Iter 2400 : training cost = 0.4831
# Iter 2405 : training cost = 0.4830
# Iter 2410 : training cost = 0.4828
# Iter 2415 : training cost = 0.4827
# Iter 2420 : training cost = 0.4826
# Iter 2425 : training cost = 0.4824
# Iter 2430 : training cost = 0.4823
# Iter 2435 : training cost = 0.4822
# Iter 2440 : training cost = 0.4820
# Iter 2445 : training cost = 0.4819
# Iter 2450 : training cost = 0.4817
# Iter 2455 : training cost = 0.4816
# Iter 2460 : training cost = 0.4815
# Iter 2465 : training cost = 0.4813
# Iter 2470 : training cost = 0.4812
# Iter 2475 : training cost = 0.4811
# Iter 2480 : training cost = 0.4809
# Iter 2485 : training cost = 0.4808
# Iter 2490 : training cost = 0.4807
# Iter 2495 : training cost = 0.4805
# Iter 2500 : training cost = 0.4804
# Iter 2505 : training cost = 0.4803
# Iter 2510 : training cost = 0.4801
# Iter 2515 : training cost = 0.4800
# Iter 2520 : training cost = 0.4799
# Iter 2525 : training cost = 0.4797
# Iter 2530 : training cost = 0.4796
# Iter 2535 : training cost = 0.4795
# Iter 2540 : training cost = 0.4793
# Iter 2545 : training cost = 0.4792
# Iter 2550 : training cost = 0.4791
# Iter 2555 : training cost = 0.4789
# Iter 2560 : training cost = 0.4788
# Iter 2565 : training cost = 0.4787
# Iter 2570 : training cost = 0.4785
# Iter 2575 : training cost = 0.4784
# Iter 2580 : training cost = 0.4783
# Iter 2585 : training cost = 0.4782
# Iter 2590 : training cost = 0.4780
# Iter 2595 : training cost = 0.4779
# Iter 2600 : training cost = 0.4778
# Iter 2605 : training cost = 0.4776
# Iter 2610 : training cost = 0.4775
# Iter 2615 : training cost = 0.4774
# Iter 2620 : training cost = 0.4773
# Iter 2625 : training cost = 0.4771
# Iter 2630 : training cost = 0.4770
# Iter 2635 : training cost = 0.4769
# Iter 2640 : training cost = 0.4768
# Iter 2645 : training cost = 0.4766
# Iter 2650 : training cost = 0.4765
# Iter 2655 : training cost = 0.4764
# Iter 2660 : training cost = 0.4763
# Iter 2665 : training cost = 0.4761
# Iter 2670 : training cost = 0.4760
# Iter 2675 : training cost = 0.4759
# Iter 2680 : training cost = 0.4758
# Iter 2685 : training cost = 0.4756
# Iter 2690 : training cost = 0.4755
# Iter 2695 : training cost = 0.4754
# Iter 2700 : training cost = 0.4753
# Iter 2705 : training cost = 0.4751
# Iter 2710 : training cost = 0.4750
# Iter 2715 : training cost = 0.4749
# Iter 2720 : training cost = 0.4748
# Iter 2725 : training cost = 0.4747
# Iter 2730 : training cost = 0.4745
# Iter 2735 : training cost = 0.4744
# Iter 2740 : training cost = 0.4743
# Iter 2745 : training cost = 0.4742
# Iter 2750 : training cost = 0.4741
# Iter 2755 : training cost = 0.4739
# Iter 2760 : training cost = 0.4738
# Iter 2765 : training cost = 0.4737
# Iter 2770 : training cost = 0.4736
# Iter 2775 : training cost = 0.4735
# Iter 2780 : training cost = 0.4733
# Iter 2785 : training cost = 0.4732
# Iter 2790 : training cost = 0.4731
# Iter 2795 : training cost = 0.4730
# Iter 2800 : training cost = 0.4729
# Iter 2805 : training cost = 0.4727
# Iter 2810 : training cost = 0.4726
# Iter 2815 : training cost = 0.4725
# Iter 2820 : training cost = 0.4724
# Iter 2825 : training cost = 0.4723
# Iter 2830 : training cost = 0.4722
# Iter 2835 : training cost = 0.4720
# Iter 2840 : training cost = 0.4719
# Iter 2845 : training cost = 0.4718
# Iter 2850 : training cost = 0.4717
# Iter 2855 : training cost = 0.4716
# Iter 2860 : training cost = 0.4715
# Iter 2865 : training cost = 0.4713
# Iter 2870 : training cost = 0.4712
# Iter 2875 : training cost = 0.4711
# Iter 2880 : training cost = 0.4710
# Iter 2885 : training cost = 0.4709
# Iter 2890 : training cost = 0.4708
# Iter 2895 : training cost = 0.4707
# Iter 2900 : training cost = 0.4705
# Iter 2905 : training cost = 0.4704
# Iter 2910 : training cost = 0.4703
# Iter 2915 : training cost = 0.4702
# Iter 2920 : training cost = 0.4701
# Iter 2925 : training cost = 0.4700
# Iter 2930 : training cost = 0.4699
# Iter 2935 : training cost = 0.4698
# Iter 2940 : training cost = 0.4696
# Iter 2945 : training cost = 0.4695
# Iter 2950 : training cost = 0.4694
# Iter 2955 : training cost = 0.4693
# Iter 2960 : training cost = 0.4692
# Iter 2965 : training cost = 0.4691
# Iter 2970 : training cost = 0.4690
# Iter 2975 : training cost = 0.4689
# Iter 2980 : training cost = 0.4688
# Iter 2985 : training cost = 0.4687
# Iter 2990 : training cost = 0.4685
# Iter 2995 : training cost = 0.4684
# Iter 3000 : training cost = 0.4683
# Iter 3005 : training cost = 0.4682
# Iter 3010 : training cost = 0.4681
# Iter 3015 : training cost = 0.4680
# Iter 3020 : training cost = 0.4679
# Iter 3025 : training cost = 0.4678
# Iter 3030 : training cost = 0.4677
# Iter 3035 : training cost = 0.4676
# Iter 3040 : training cost = 0.4675
# Iter 3045 : training cost = 0.4673
# Iter 3050 : training cost = 0.4672
# Iter 3055 : training cost = 0.4671
# Iter 3060 : training cost = 0.4670
# Iter 3065 : training cost = 0.4669
# Iter 3070 : training cost = 0.4668
# Iter 3075 : training cost = 0.4667
# Iter 3080 : training cost = 0.4666
# Iter 3085 : training cost = 0.4665
# Iter 3090 : training cost = 0.4664
# Iter 3095 : training cost = 0.4663
# Iter 3100 : training cost = 0.4662
# Iter 3105 : training cost = 0.4661
# Iter 3110 : training cost = 0.4660
# Iter 3115 : training cost = 0.4659
# Iter 3120 : training cost = 0.4658
# Iter 3125 : training cost = 0.4657
# Iter 3130 : training cost = 0.4656
# Iter 3135 : training cost = 0.4654
# Iter 3140 : training cost = 0.4653
# Iter 3145 : training cost = 0.4652
# Iter 3150 : training cost = 0.4651
# Iter 3155 : training cost = 0.4650
# Iter 3160 : training cost = 0.4649
# Iter 3165 : training cost = 0.4648
# Iter 3170 : training cost = 0.4647
# Iter 3175 : training cost = 0.4646
# Iter 3180 : training cost = 0.4645
# Iter 3185 : training cost = 0.4644
# Iter 3190 : training cost = 0.4643
# Iter 3195 : training cost = 0.4642
# Iter 3200 : training cost = 0.4641
# Iter 3205 : training cost = 0.4640
# Iter 3210 : training cost = 0.4639
# Iter 3215 : training cost = 0.4638
# Iter 3220 : training cost = 0.4637
# Iter 3225 : training cost = 0.4636
# Iter 3230 : training cost = 0.4635
# Iter 3235 : training cost = 0.4634
# Iter 3240 : training cost = 0.4633
# Iter 3245 : training cost = 0.4632
# Iter 3250 : training cost = 0.4631
# Iter 3255 : training cost = 0.4630
# Iter 3260 : training cost = 0.4629
# Iter 3265 : training cost = 0.4628
# Iter 3270 : training cost = 0.4627
# Iter 3275 : training cost = 0.4626
# Iter 3280 : training cost = 0.4625
# Iter 3285 : training cost = 0.4624
# Iter 3290 : training cost = 0.4623
# Iter 3295 : training cost = 0.4622
# Iter 3300 : training cost = 0.4621
# Iter 3305 : training cost = 0.4620
# Iter 3310 : training cost = 0.4619
# Iter 3315 : training cost = 0.4618
# Iter 3320 : training cost = 0.4617
# Iter 3325 : training cost = 0.4616
# Iter 3330 : training cost = 0.4615
# Iter 3335 : training cost = 0.4614
# Iter 3340 : training cost = 0.4613
# Iter 3345 : training cost = 0.4612
# Iter 3350 : training cost = 0.4611
# Iter 3355 : training cost = 0.4611
# Iter 3360 : training cost = 0.4610
# Iter 3365 : training cost = 0.4609
# Iter 3370 : training cost = 0.4608
# Iter 3375 : training cost = 0.4607
# Iter 3380 : training cost = 0.4606
# Iter 3385 : training cost = 0.4605
# Iter 3390 : training cost = 0.4604
# Iter 3395 : training cost = 0.4603
# Iter 3400 : training cost = 0.4602
# Iter 3405 : training cost = 0.4601
# Iter 3410 : training cost = 0.4600
# Iter 3415 : training cost = 0.4599
# Iter 3420 : training cost = 0.4598
# Iter 3425 : training cost = 0.4597
# Iter 3430 : training cost = 0.4596
# Iter 3435 : training cost = 0.4595
# Iter 3440 : training cost = 0.4594
# Iter 3445 : training cost = 0.4593
# Iter 3450 : training cost = 0.4593
# Iter 3455 : training cost = 0.4592
# Iter 3460 : training cost = 0.4591
# Iter 3465 : training cost = 0.4590
# Iter 3470 : training cost = 0.4589
# Iter 3475 : training cost = 0.4588
# Iter 3480 : training cost = 0.4587
# Iter 3485 : training cost = 0.4586
# Iter 3490 : training cost = 0.4585
# Iter 3495 : training cost = 0.4584
# Iter 3500 : training cost = 0.4583
# Iter 3505 : training cost = 0.4582
# Iter 3510 : training cost = 0.4581
# Iter 3515 : training cost = 0.4581
# Iter 3520 : training cost = 0.4580
# Iter 3525 : training cost = 0.4579
# Iter 3530 : training cost = 0.4578
# Iter 3535 : training cost = 0.4577
# Iter 3540 : training cost = 0.4576
# Iter 3545 : training cost = 0.4575
# Iter 3550 : training cost = 0.4574
# Iter 3555 : training cost = 0.4573
# Iter 3560 : training cost = 0.4572
# Iter 3565 : training cost = 0.4572
# Iter 3570 : training cost = 0.4571
# Iter 3575 : training cost = 0.4570
# Iter 3580 : training cost = 0.4569
# Iter 3585 : training cost = 0.4568
# Iter 3590 : training cost = 0.4567
# Iter 3595 : training cost = 0.4566
# Iter 3600 : training cost = 0.4565
# Iter 3605 : training cost = 0.4564
# Iter 3610 : training cost = 0.4564
# Iter 3615 : training cost = 0.4563
# Iter 3620 : training cost = 0.4562
# Iter 3625 : training cost = 0.4561
# Iter 3630 : training cost = 0.4560
# Iter 3635 : training cost = 0.4559
# Iter 3640 : training cost = 0.4558
# Iter 3645 : training cost = 0.4557
# Iter 3650 : training cost = 0.4557
# Iter 3655 : training cost = 0.4556
# Iter 3660 : training cost = 0.4555
# Iter 3665 : training cost = 0.4554
# Iter 3670 : training cost = 0.4553
# Iter 3675 : training cost = 0.4552
# Iter 3680 : training cost = 0.4551
# Iter 3685 : training cost = 0.4550
# Iter 3690 : training cost = 0.4550
# Iter 3695 : training cost = 0.4549
# Iter 3700 : training cost = 0.4548
# Iter 3705 : training cost = 0.4547
# Iter 3710 : training cost = 0.4546
# Iter 3715 : training cost = 0.4545
# Iter 3720 : training cost = 0.4544
# Iter 3725 : training cost = 0.4544
# Iter 3730 : training cost = 0.4543
# Iter 3735 : training cost = 0.4542
# Iter 3740 : training cost = 0.4541
# Iter 3745 : training cost = 0.4540
# Iter 3750 : training cost = 0.4539
# Iter 3755 : training cost = 0.4539
# Iter 3760 : training cost = 0.4538
# Iter 3765 : training cost = 0.4537
# Iter 3770 : training cost = 0.4536
# Iter 3775 : training cost = 0.4535
# Iter 3780 : training cost = 0.4534
# Iter 3785 : training cost = 0.4533
# Iter 3790 : training cost = 0.4533
# Iter 3795 : training cost = 0.4532
# Iter 3800 : training cost = 0.4531
# Iter 3805 : training cost = 0.4530
# Iter 3810 : training cost = 0.4529
# Iter 3815 : training cost = 0.4529
# Iter 3820 : training cost = 0.4528
# Iter 3825 : training cost = 0.4527
# Iter 3830 : training cost = 0.4526
# Iter 3835 : training cost = 0.4525
# Iter 3840 : training cost = 0.4524
# Iter 3845 : training cost = 0.4524
# Iter 3850 : training cost = 0.4523
# Iter 3855 : training cost = 0.4522
# Iter 3860 : training cost = 0.4521
# Iter 3865 : training cost = 0.4520
# Iter 3870 : training cost = 0.4519
# Iter 3875 : training cost = 0.4519
# Iter 3880 : training cost = 0.4518
# Iter 3885 : training cost = 0.4517
# Iter 3890 : training cost = 0.4516
# Iter 3895 : training cost = 0.4515
# Iter 3900 : training cost = 0.4515
# Iter 3905 : training cost = 0.4514
# Iter 3910 : training cost = 0.4513
# Iter 3915 : training cost = 0.4512
# Iter 3920 : training cost = 0.4511
# Iter 3925 : training cost = 0.4511
# Iter 3930 : training cost = 0.4510
# Iter 3935 : training cost = 0.4509
# Iter 3940 : training cost = 0.4508
# Iter 3945 : training cost = 0.4507
# Iter 3950 : training cost = 0.4507
# Iter 3955 : training cost = 0.4506
# Iter 3960 : training cost = 0.4505
# Iter 3965 : training cost = 0.4504
# Iter 3970 : training cost = 0.4503
# Iter 3975 : training cost = 0.4503
# Iter 3980 : training cost = 0.4502
# Iter 3985 : training cost = 0.4501
# Iter 3990 : training cost = 0.4500
# Iter 3995 : training cost = 0.4500
# Iter 4000 : training cost = 0.4499
# Iter 4005 : training cost = 0.4498
# Iter 4010 : training cost = 0.4497
# Iter 4015 : training cost = 0.4496
# Iter 4020 : training cost = 0.4496
# Iter 4025 : training cost = 0.4495
# Iter 4030 : training cost = 0.4494
# Iter 4035 : training cost = 0.4493
# Iter 4040 : training cost = 0.4493
# Iter 4045 : training cost = 0.4492
# Iter 4050 : training cost = 0.4491
# Iter 4055 : training cost = 0.4490
# Iter 4060 : training cost = 0.4490
# Iter 4065 : training cost = 0.4489
# Iter 4070 : training cost = 0.4488
# Iter 4075 : training cost = 0.4487
# Iter 4080 : training cost = 0.4486
# Iter 4085 : training cost = 0.4486
# Iter 4090 : training cost = 0.4485
# Iter 4095 : training cost = 0.4484
# Iter 4100 : training cost = 0.4483
# Iter 4105 : training cost = 0.4483
# Iter 4110 : training cost = 0.4482
# Iter 4115 : training cost = 0.4481
# Iter 4120 : training cost = 0.4480
# Iter 4125 : training cost = 0.4480
# Iter 4130 : training cost = 0.4479
# Iter 4135 : training cost = 0.4478
# Iter 4140 : training cost = 0.4477
# Iter 4145 : training cost = 0.4477
# Iter 4150 : training cost = 0.4476
# Iter 4155 : training cost = 0.4475
# Iter 4160 : training cost = 0.4474
# Iter 4165 : training cost = 0.4474
# Iter 4170 : training cost = 0.4473
# Iter 4175 : training cost = 0.4472
# Iter 4180 : training cost = 0.4471
# Iter 4185 : training cost = 0.4471
# Iter 4190 : training cost = 0.4470
# Iter 4195 : training cost = 0.4469
# Iter 4200 : training cost = 0.4468
# Iter 4205 : training cost = 0.4468
# Iter 4210 : training cost = 0.4467
# Iter 4215 : training cost = 0.4466
# Iter 4220 : training cost = 0.4466
# Iter 4225 : training cost = 0.4465
# Iter 4230 : training cost = 0.4464
# Iter 4235 : training cost = 0.4463
# Iter 4240 : training cost = 0.4463
# Iter 4245 : training cost = 0.4462
# Iter 4250 : training cost = 0.4461
# Iter 4255 : training cost = 0.4460
# Iter 4260 : training cost = 0.4460
# Iter 4265 : training cost = 0.4459
# Iter 4270 : training cost = 0.4458
# Iter 4275 : training cost = 0.4458
# Iter 4280 : training cost = 0.4457
# Iter 4285 : training cost = 0.4456
# Iter 4290 : training cost = 0.4455
# Iter 4295 : training cost = 0.4455
# Iter 4300 : training cost = 0.4454
# Iter 4305 : training cost = 0.4453
# Iter 4310 : training cost = 0.4453
# Iter 4315 : training cost = 0.4452
# Iter 4320 : training cost = 0.4451
# Iter 4325 : training cost = 0.4450
# Iter 4330 : training cost = 0.4450
# Iter 4335 : training cost = 0.4449
# Iter 4340 : training cost = 0.4448
# Iter 4345 : training cost = 0.4448
# Iter 4350 : training cost = 0.4447
# Iter 4355 : training cost = 0.4446
# Iter 4360 : training cost = 0.4445
# Iter 4365 : training cost = 0.4445
# Iter 4370 : training cost = 0.4444
# Iter 4375 : training cost = 0.4443
# Iter 4380 : training cost = 0.4443
# Iter 4385 : training cost = 0.4442
# Iter 4390 : training cost = 0.4441
# Iter 4395 : training cost = 0.4441
# Iter 4400 : training cost = 0.4440
# Iter 4405 : training cost = 0.4439
# Iter 4410 : training cost = 0.4439
# Iter 4415 : training cost = 0.4438
# Iter 4420 : training cost = 0.4437
# Iter 4425 : training cost = 0.4436
# Iter 4430 : training cost = 0.4436
# Iter 4435 : training cost = 0.4435
# Iter 4440 : training cost = 0.4434
# Iter 4445 : training cost = 0.4434
# Iter 4450 : training cost = 0.4433
# Iter 4455 : training cost = 0.4432
# Iter 4460 : training cost = 0.4432
# Iter 4465 : training cost = 0.4431
# Iter 4470 : training cost = 0.4430
# Iter 4475 : training cost = 0.4430
# Iter 4480 : training cost = 0.4429
# Iter 4485 : training cost = 0.4428
# Iter 4490 : training cost = 0.4428
# Iter 4495 : training cost = 0.4427
# Iter 4500 : training cost = 0.4426
# Iter 4505 : training cost = 0.4426
# Iter 4510 : training cost = 0.4425
# Iter 4515 : training cost = 0.4424
# Iter 4520 : training cost = 0.4424
# Iter 4525 : training cost = 0.4423
# Iter 4530 : training cost = 0.4422
# Iter 4535 : training cost = 0.4422
# Iter 4540 : training cost = 0.4421
# Iter 4545 : training cost = 0.4420
# Iter 4550 : training cost = 0.4420
# Iter 4555 : training cost = 0.4419
# Iter 4560 : training cost = 0.4418
# Iter 4565 : training cost = 0.4418
# Iter 4570 : training cost = 0.4417
# Iter 4575 : training cost = 0.4416
# Iter 4580 : training cost = 0.4416
# Iter 4585 : training cost = 0.4415
# Iter 4590 : training cost = 0.4414
# Iter 4595 : training cost = 0.4414
# Iter 4600 : training cost = 0.4413
# Iter 4605 : training cost = 0.4412
# Iter 4610 : training cost = 0.4412
# Iter 4615 : training cost = 0.4411
# Iter 4620 : training cost = 0.4410
# Iter 4625 : training cost = 0.4410
# Iter 4630 : training cost = 0.4409
# Iter 4635 : training cost = 0.4408
# Iter 4640 : training cost = 0.4408
# Iter 4645 : training cost = 0.4407
# Iter 4650 : training cost = 0.4406
# Iter 4655 : training cost = 0.4406
# Iter 4660 : training cost = 0.4405
# Iter 4665 : training cost = 0.4404
# Iter 4670 : training cost = 0.4404
# Iter 4675 : training cost = 0.4403
# Iter 4680 : training cost = 0.4403
# Iter 4685 : training cost = 0.4402
# Iter 4690 : training cost = 0.4401
# Iter 4695 : training cost = 0.4401
# Iter 4700 : training cost = 0.4400
# Iter 4705 : training cost = 0.4399
# Iter 4710 : training cost = 0.4399
# Iter 4715 : training cost = 0.4398
# Iter 4720 : training cost = 0.4397
# Iter 4725 : training cost = 0.4397
# Iter 4730 : training cost = 0.4396
# Iter 4735 : training cost = 0.4395
# Iter 4740 : training cost = 0.4395
# Iter 4745 : training cost = 0.4394
# Iter 4750 : training cost = 0.4394
# Iter 4755 : training cost = 0.4393
# Iter 4760 : training cost = 0.4392
# Iter 4765 : training cost = 0.4392
# Iter 4770 : training cost = 0.4391
# Iter 4775 : training cost = 0.4390
# Iter 4780 : training cost = 0.4390
# Iter 4785 : training cost = 0.4389
# Iter 4790 : training cost = 0.4389
# Iter 4795 : training cost = 0.4388
# Iter 4800 : training cost = 0.4387
# Iter 4805 : training cost = 0.4387
# Iter 4810 : training cost = 0.4386
# Iter 4815 : training cost = 0.4385
# Iter 4820 : training cost = 0.4385
# Iter 4825 : training cost = 0.4384
# Iter 4830 : training cost = 0.4384
# Iter 4835 : training cost = 0.4383
# Iter 4840 : training cost = 0.4382
# Iter 4845 : training cost = 0.4382
# Iter 4850 : training cost = 0.4381
# Iter 4855 : training cost = 0.4381
# Iter 4860 : training cost = 0.4380
# Iter 4865 : training cost = 0.4379
# Iter 4870 : training cost = 0.4379
# Iter 4875 : training cost = 0.4378
# Iter 4880 : training cost = 0.4378
# Iter 4885 : training cost = 0.4377
# Iter 4890 : training cost = 0.4376
# Iter 4895 : training cost = 0.4376
# Iter 4900 : training cost = 0.4375
# Iter 4905 : training cost = 0.4374
# Iter 4910 : training cost = 0.4374
# Iter 4915 : training cost = 0.4373
# Iter 4920 : training cost = 0.4373
# Iter 4925 : training cost = 0.4372
# Iter 4930 : training cost = 0.4371
# Iter 4935 : training cost = 0.4371
# Iter 4940 : training cost = 0.4370
# Iter 4945 : training cost = 0.4370
# Iter 4950 : training cost = 0.4369
# Iter 4955 : training cost = 0.4368
# Iter 4960 : training cost = 0.4368
# Iter 4965 : training cost = 0.4367
# Iter 4970 : training cost = 0.4367
# Iter 4975 : training cost = 0.4366
# Iter 4980 : training cost = 0.4366
# Iter 4985 : training cost = 0.4365
# Iter 4990 : training cost = 0.4364
# Iter 4995 : training cost = 0.4364
# Iter 5000 : training cost = 0.4363
# Iter 5005 : training cost = 0.4363
# Iter 5010 : training cost = 0.4362
# Iter 5015 : training cost = 0.4361
# Iter 5020 : training cost = 0.4361
# Iter 5025 : training cost = 0.4360
# Iter 5030 : training cost = 0.4360
# Iter 5035 : training cost = 0.4359
# Iter 5040 : training cost = 0.4358
# Iter 5045 : training cost = 0.4358
# Iter 5050 : training cost = 0.4357
# Iter 5055 : training cost = 0.4357
# Iter 5060 : training cost = 0.4356
# Iter 5065 : training cost = 0.4356
# Iter 5070 : training cost = 0.4355
# Iter 5075 : training cost = 0.4354
# Iter 5080 : training cost = 0.4354
# Iter 5085 : training cost = 0.4353
# Iter 5090 : training cost = 0.4353
# Iter 5095 : training cost = 0.4352
# Iter 5100 : training cost = 0.4352
# Iter 5105 : training cost = 0.4351
# Iter 5110 : training cost = 0.4350
# Iter 5115 : training cost = 0.4350
# Iter 5120 : training cost = 0.4349
# Iter 5125 : training cost = 0.4349
# Iter 5130 : training cost = 0.4348
# Iter 5135 : training cost = 0.4348
# Iter 5140 : training cost = 0.4347
# Iter 5145 : training cost = 0.4346
# Iter 5150 : training cost = 0.4346
# Iter 5155 : training cost = 0.4345
# Iter 5160 : training cost = 0.4345
# Iter 5165 : training cost = 0.4344
# Iter 5170 : training cost = 0.4344
# Iter 5175 : training cost = 0.4343
# Iter 5180 : training cost = 0.4342
# Iter 5185 : training cost = 0.4342
# Iter 5190 : training cost = 0.4341
# Iter 5195 : training cost = 0.4341
# Iter 5200 : training cost = 0.4340
# Iter 5205 : training cost = 0.4340
# Iter 5210 : training cost = 0.4339
# Iter 5215 : training cost = 0.4339
# Iter 5220 : training cost = 0.4338
# Iter 5225 : training cost = 0.4337
# Iter 5230 : training cost = 0.4337
# Iter 5235 : training cost = 0.4336
# Iter 5240 : training cost = 0.4336
# Iter 5245 : training cost = 0.4335
# Iter 5250 : training cost = 0.4335
# Iter 5255 : training cost = 0.4334
# Iter 5260 : training cost = 0.4334
# Iter 5265 : training cost = 0.4333
# Iter 5270 : training cost = 0.4332
# Iter 5275 : training cost = 0.4332
# Iter 5280 : training cost = 0.4331
# Iter 5285 : training cost = 0.4331
# Iter 5290 : training cost = 0.4330
# Iter 5295 : training cost = 0.4330
# Iter 5300 : training cost = 0.4329
# Iter 5305 : training cost = 0.4329
# Iter 5310 : training cost = 0.4328
# Iter 5315 : training cost = 0.4328
# Iter 5320 : training cost = 0.4327
# Iter 5325 : training cost = 0.4326
# Iter 5330 : training cost = 0.4326
# Iter 5335 : training cost = 0.4325
# Iter 5340 : training cost = 0.4325
# Iter 5345 : training cost = 0.4324
# Iter 5350 : training cost = 0.4324
# Iter 5355 : training cost = 0.4323
# Iter 5360 : training cost = 0.4323
# Iter 5365 : training cost = 0.4322
# Iter 5370 : training cost = 0.4322
# Iter 5375 : training cost = 0.4321
# Iter 5380 : training cost = 0.4321
# Iter 5385 : training cost = 0.4320
# Iter 5390 : training cost = 0.4319
# Iter 5395 : training cost = 0.4319
# Iter 5400 : training cost = 0.4318
# Iter 5405 : training cost = 0.4318
# Iter 5410 : training cost = 0.4317
# Iter 5415 : training cost = 0.4317
# Iter 5420 : training cost = 0.4316
# Iter 5425 : training cost = 0.4316
# Iter 5430 : training cost = 0.4315
# Iter 5435 : training cost = 0.4315
# Iter 5440 : training cost = 0.4314
# Iter 5445 : training cost = 0.4314
# Iter 5450 : training cost = 0.4313
# Iter 5455 : training cost = 0.4313
# Iter 5460 : training cost = 0.4312
# Iter 5465 : training cost = 0.4312
# Iter 5470 : training cost = 0.4311
# Iter 5475 : training cost = 0.4310
# Iter 5480 : training cost = 0.4310
# Iter 5485 : training cost = 0.4309
# Iter 5490 : training cost = 0.4309
# Iter 5495 : training cost = 0.4308
# Iter 5500 : training cost = 0.4308
# Iter 5505 : training cost = 0.4307
# Iter 5510 : training cost = 0.4307
# Iter 5515 : training cost = 0.4306
# Iter 5520 : training cost = 0.4306
# Iter 5525 : training cost = 0.4305
# Iter 5530 : training cost = 0.4305
# Iter 5535 : training cost = 0.4304
# Iter 5540 : training cost = 0.4304
# Iter 5545 : training cost = 0.4303
# Iter 5550 : training cost = 0.4303
# Iter 5555 : training cost = 0.4302
# Iter 5560 : training cost = 0.4302
# Iter 5565 : training cost = 0.4301
# Iter 5570 : training cost = 0.4301
# Iter 5575 : training cost = 0.4300
# Iter 5580 : training cost = 0.4300
# Iter 5585 : training cost = 0.4299
# Iter 5590 : training cost = 0.4299
# Iter 5595 : training cost = 0.4298
# Iter 5600 : training cost = 0.4298
# Iter 5605 : training cost = 0.4297
# Iter 5610 : training cost = 0.4297
# Iter 5615 : training cost = 0.4296
# Iter 5620 : training cost = 0.4296
# Iter 5625 : training cost = 0.4295
# Iter 5630 : training cost = 0.4295
# Iter 5635 : training cost = 0.4294
# Iter 5640 : training cost = 0.4294
# Iter 5645 : training cost = 0.4293
# Iter 5650 : training cost = 0.4293
# Iter 5655 : training cost = 0.4292
# Iter 5660 : training cost = 0.4292
# Iter 5665 : training cost = 0.4291
# Iter 5670 : training cost = 0.4291
# Iter 5675 : training cost = 0.4290
# Iter 5680 : training cost = 0.4290
# Iter 5685 : training cost = 0.4289
# Iter 5690 : training cost = 0.4289
# Iter 5695 : training cost = 0.4288
# Iter 5700 : training cost = 0.4288
# Iter 5705 : training cost = 0.4287
# Iter 5710 : training cost = 0.4287
# Iter 5715 : training cost = 0.4286
# Iter 5720 : training cost = 0.4286
# Iter 5725 : training cost = 0.4285
# Iter 5730 : training cost = 0.4285
# Iter 5735 : training cost = 0.4284
# Iter 5740 : training cost = 0.4284
# Iter 5745 : training cost = 0.4283
# Iter 5750 : training cost = 0.4283
# Iter 5755 : training cost = 0.4282
# Iter 5760 : training cost = 0.4282
# Iter 5765 : training cost = 0.4281
# Iter 5770 : training cost = 0.4281
# Iter 5775 : training cost = 0.4280
# Iter 5780 : training cost = 0.4280
# Iter 5785 : training cost = 0.4279
# Iter 5790 : training cost = 0.4279
# Iter 5795 : training cost = 0.4278
# Iter 5800 : training cost = 0.4278
# Iter 5805 : training cost = 0.4277
# Iter 5810 : training cost = 0.4277
# Iter 5815 : training cost = 0.4276
# Iter 5820 : training cost = 0.4276
# Iter 5825 : training cost = 0.4275
# Iter 5830 : training cost = 0.4275
# Iter 5835 : training cost = 0.4275
# Iter 5840 : training cost = 0.4274
# Iter 5845 : training cost = 0.4274
# Iter 5850 : training cost = 0.4273
# Iter 5855 : training cost = 0.4273
# Iter 5860 : training cost = 0.4272
# Iter 5865 : training cost = 0.4272
# Iter 5870 : training cost = 0.4271
# Iter 5875 : training cost = 0.4271
# Iter 5880 : training cost = 0.4270
# Iter 5885 : training cost = 0.4270
# Iter 5890 : training cost = 0.4269
# Iter 5895 : training cost = 0.4269
# Iter 5900 : training cost = 0.4268
# Iter 5905 : training cost = 0.4268
# Iter 5910 : training cost = 0.4267
# Iter 5915 : training cost = 0.4267
# Iter 5920 : training cost = 0.4267
# Iter 5925 : training cost = 0.4266
# Iter 5930 : training cost = 0.4266
# Iter 5935 : training cost = 0.4265
# Iter 5940 : training cost = 0.4265
# Iter 5945 : training cost = 0.4264
# Iter 5950 : training cost = 0.4264
# Iter 5955 : training cost = 0.4263
# Iter 5960 : training cost = 0.4263
# Iter 5965 : training cost = 0.4262
# Iter 5970 : training cost = 0.4262
# Iter 5975 : training cost = 0.4261
# Iter 5980 : training cost = 0.4261
# Iter 5985 : training cost = 0.4260
# Iter 5990 : training cost = 0.4260
# Iter 5995 : training cost = 0.4260
# Iter 6000 : training cost = 0.4259
# Iter 6005 : training cost = 0.4259
# Iter 6010 : training cost = 0.4258
# Iter 6015 : training cost = 0.4258
# Iter 6020 : training cost = 0.4257
# Iter 6025 : training cost = 0.4257
# Iter 6030 : training cost = 0.4256
# Iter 6035 : training cost = 0.4256
# Iter 6040 : training cost = 0.4255
# Iter 6045 : training cost = 0.4255
# Iter 6050 : training cost = 0.4255
# Iter 6055 : training cost = 0.4254
# Iter 6060 : training cost = 0.4254
# Iter 6065 : training cost = 0.4253
# Iter 6070 : training cost = 0.4253
# Iter 6075 : training cost = 0.4252
# Iter 6080 : training cost = 0.4252
# Iter 6085 : training cost = 0.4251
# Iter 6090 : training cost = 0.4251
# Iter 6095 : training cost = 0.4250
# Iter 6100 : training cost = 0.4250
# Iter 6105 : training cost = 0.4250
# Iter 6110 : training cost = 0.4249
# Iter 6115 : training cost = 0.4249
# Iter 6120 : training cost = 0.4248
# Iter 6125 : training cost = 0.4248
# Iter 6130 : training cost = 0.4247
# Iter 6135 : training cost = 0.4247
# Iter 6140 : training cost = 0.4246
# Iter 6145 : training cost = 0.4246
# Iter 6150 : training cost = 0.4246
# Iter 6155 : training cost = 0.4245
# Iter 6160 : training cost = 0.4245
# Iter 6165 : training cost = 0.4244
# Iter 6170 : training cost = 0.4244
# Iter 6175 : training cost = 0.4243
# Iter 6180 : training cost = 0.4243
# Iter 6185 : training cost = 0.4242
# Iter 6190 : training cost = 0.4242
# Iter 6195 : training cost = 0.4242
# Iter 6200 : training cost = 0.4241
# Iter 6205 : training cost = 0.4241
# Iter 6210 : training cost = 0.4240
# Iter 6215 : training cost = 0.4240
# Iter 6220 : training cost = 0.4239
# Iter 6225 : training cost = 0.4239
# Iter 6230 : training cost = 0.4239
# Iter 6235 : training cost = 0.4238
# Iter 6240 : training cost = 0.4238
# Iter 6245 : training cost = 0.4237
# Iter 6250 : training cost = 0.4237
# Iter 6255 : training cost = 0.4236
# Iter 6260 : training cost = 0.4236
# Iter 6265 : training cost = 0.4235
# Iter 6270 : training cost = 0.4235
# Iter 6275 : training cost = 0.4235
# Iter 6280 : training cost = 0.4234
# Iter 6285 : training cost = 0.4234
# Iter 6290 : training cost = 0.4233
# Iter 6295 : training cost = 0.4233
# Iter 6300 : training cost = 0.4232
# Iter 6305 : training cost = 0.4232
# Iter 6310 : training cost = 0.4232
# Iter 6315 : training cost = 0.4231
# Iter 6320 : training cost = 0.4231
# Iter 6325 : training cost = 0.4230
# Iter 6330 : training cost = 0.4230
# Iter 6335 : training cost = 0.4229
# Iter 6340 : training cost = 0.4229
# Iter 6345 : training cost = 0.4229
# Iter 6350 : training cost = 0.4228
# Iter 6355 : training cost = 0.4228
# Iter 6360 : training cost = 0.4227
# Iter 6365 : training cost = 0.4227
# Iter 6370 : training cost = 0.4227
# Iter 6375 : training cost = 0.4226
# Iter 6380 : training cost = 0.4226
# Iter 6385 : training cost = 0.4225
# Iter 6390 : training cost = 0.4225
# Iter 6395 : training cost = 0.4224
# Iter 6400 : training cost = 0.4224
# Iter 6405 : training cost = 0.4224
# Iter 6410 : training cost = 0.4223
# Iter 6415 : training cost = 0.4223
# Iter 6420 : training cost = 0.4222
# Iter 6425 : training cost = 0.4222
# Iter 6430 : training cost = 0.4222
# Iter 6435 : training cost = 0.4221
# Iter 6440 : training cost = 0.4221
# Iter 6445 : training cost = 0.4220
# Iter 6450 : training cost = 0.4220
# Iter 6455 : training cost = 0.4219
# Iter 6460 : training cost = 0.4219
# Iter 6465 : training cost = 0.4219
# Iter 6470 : training cost = 0.4218
# Iter 6475 : training cost = 0.4218
# Iter 6480 : training cost = 0.4217
# Iter 6485 : training cost = 0.4217
# Iter 6490 : training cost = 0.4217
# Iter 6495 : training cost = 0.4216
# Iter 6500 : training cost = 0.4216
# Iter 6505 : training cost = 0.4215
# Iter 6510 : training cost = 0.4215
# Iter 6515 : training cost = 0.4215
# Iter 6520 : training cost = 0.4214
# Iter 6525 : training cost = 0.4214
# Iter 6530 : training cost = 0.4213
# Iter 6535 : training cost = 0.4213
# Iter 6540 : training cost = 0.4212
# Iter 6545 : training cost = 0.4212
# Iter 6550 : training cost = 0.4212
# Iter 6555 : training cost = 0.4211
# Iter 6560 : training cost = 0.4211
# Iter 6565 : training cost = 0.4210
# Iter 6570 : training cost = 0.4210
# Iter 6575 : training cost = 0.4210
# Iter 6580 : training cost = 0.4209
# Iter 6585 : training cost = 0.4209
# Iter 6590 : training cost = 0.4208
# Iter 6595 : training cost = 0.4208
# Iter 6600 : training cost = 0.4208
# Iter 6605 : training cost = 0.4207
# Iter 6610 : training cost = 0.4207
# Iter 6615 : training cost = 0.4206
# Iter 6620 : training cost = 0.4206
# Iter 6625 : training cost = 0.4206
# Iter 6630 : training cost = 0.4205
# Iter 6635 : training cost = 0.4205
# Iter 6640 : training cost = 0.4204
# Iter 6645 : training cost = 0.4204
# Iter 6650 : training cost = 0.4204
# Iter 6655 : training cost = 0.4203
# Iter 6660 : training cost = 0.4203
# Iter 6665 : training cost = 0.4203
# Iter 6670 : training cost = 0.4202
# Iter 6675 : training cost = 0.4202
# Iter 6680 : training cost = 0.4201
# Iter 6685 : training cost = 0.4201
# Iter 6690 : training cost = 0.4201
# Iter 6695 : training cost = 0.4200
# Iter 6700 : training cost = 0.4200
# Iter 6705 : training cost = 0.4199
# Iter 6710 : training cost = 0.4199
# Iter 6715 : training cost = 0.4199
# Iter 6720 : training cost = 0.4198
# Iter 6725 : training cost = 0.4198
# Iter 6730 : training cost = 0.4197
# Iter 6735 : training cost = 0.4197
# Iter 6740 : training cost = 0.4197
# Iter 6745 : training cost = 0.4196
# Iter 6750 : training cost = 0.4196
# Iter 6755 : training cost = 0.4195
# Iter 6760 : training cost = 0.4195
# Iter 6765 : training cost = 0.4195
# Iter 6770 : training cost = 0.4194
# Iter 6775 : training cost = 0.4194
# Iter 6780 : training cost = 0.4194
# Iter 6785 : training cost = 0.4193
# Iter 6790 : training cost = 0.4193
# Iter 6795 : training cost = 0.4192
# Iter 6800 : training cost = 0.4192
# Iter 6805 : training cost = 0.4192
# Iter 6810 : training cost = 0.4191
# Iter 6815 : training cost = 0.4191
# Iter 6820 : training cost = 0.4190
# Iter 6825 : training cost = 0.4190
# Iter 6830 : training cost = 0.4190
# Iter 6835 : training cost = 0.4189
# Iter 6840 : training cost = 0.4189
# Iter 6845 : training cost = 0.4189
# Iter 6850 : training cost = 0.4188
# Iter 6855 : training cost = 0.4188
# Iter 6860 : training cost = 0.4187
# Iter 6865 : training cost = 0.4187
# Iter 6870 : training cost = 0.4187
# Iter 6875 : training cost = 0.4186
# Iter 6880 : training cost = 0.4186
# ...
# Iter 97785 : training cost = 0.3641
# Iter 97790 : training cost = 0.3641
# Iter 97795 : training cost = 0.3641
# Iter 97800 : training cost = 0.3641
# Iter 97805 : training cost = 0.3641
# Iter 97810 : training cost = 0.3641
# Iter 97815 : training cost = 0.3641
# Iter 97820 : training cost = 0.3641
# Iter 97825 : training cost = 0.3641
# Iter 97830 : training cost = 0.3641
# Iter 97835 : training cost = 0.3641
# Iter 97840 : training cost = 0.3641
# Iter 97845 : training cost = 0.3641
# Iter 97850 : training cost = 0.3641
# Iter 97855 : training cost = 0.3641
# Iter 97860 : training cost = 0.3641
# Iter 97865 : training cost = 0.3641
# Iter 97870 : training cost = 0.3641
# Iter 97875 : training cost = 0.3641
# Iter 97880 : training cost = 0.3641
# Iter 97885 : training cost = 0.3641
# Iter 97890 : training cost = 0.3641
# Iter 97895 : training cost = 0.3641
# Iter 97900 : training cost = 0.3641
# Iter 97905 : training cost = 0.3641
# Iter 97910 : training cost = 0.3641
# Iter 97915 : training cost = 0.3641
# Iter 97920 : training cost = 0.3641
# Iter 97925 : training cost = 0.3641
# Iter 97930 : training cost = 0.3641
# Iter 97935 : training cost = 0.3641
# Iter 97940 : training cost = 0.3641
# Iter 97945 : training cost = 0.3641
# Iter 97950 : training cost = 0.3641
# Iter 97955 : training cost = 0.3641
# Iter 97960 : training cost = 0.3641
# Iter 97965 : training cost = 0.3641
# Iter 97970 : training cost = 0.3641
# Iter 97975 : training cost = 0.3641
# Iter 97980 : training cost = 0.3641
# Iter 97985 : training cost = 0.3641
# Iter 97990 : training cost = 0.3641
# Iter 97995 : training cost = 0.3641
# Iter 98000 : training cost = 0.3641
# Iter 98005 : training cost = 0.3641
# Iter 98010 : training cost = 0.3641
# Iter 98015 : training cost = 0.3641
# Iter 98020 : training cost = 0.3641
# Iter 98025 : training cost = 0.3641
# Iter 98030 : training cost = 0.3641
# Iter 98035 : training cost = 0.3641
# Iter 98040 : training cost = 0.3641
# Iter 98045 : training cost = 0.3640
# Iter 98050 : training cost = 0.3640
# Iter 98055 : training cost = 0.3640
# Iter 98060 : training cost = 0.3640
# Iter 98065 : training cost = 0.3640
# Iter 98070 : training cost = 0.3640
# Iter 98075 : training cost = 0.3640
# Iter 98080 : training cost = 0.3640
# Iter 98085 : training cost = 0.3640
# Iter 98090 : training cost = 0.3640
# Iter 98095 : training cost = 0.3640
# Iter 98100 : training cost = 0.3640
# Iter 98105 : training cost = 0.3640
# Iter 98110 : training cost = 0.3640
# Iter 98115 : training cost = 0.3640
# Iter 98120 : training cost = 0.3640
# Iter 98125 : training cost = 0.3640
# Iter 98130 : training cost = 0.3640
# Iter 98135 : training cost = 0.3640
# Iter 98140 : training cost = 0.3640
# Iter 98145 : training cost = 0.3640
# Iter 98150 : training cost = 0.3640
# Iter 98155 : training cost = 0.3640
# Iter 98160 : training cost = 0.3640
# Iter 98165 : training cost = 0.3640
# Iter 98170 : training cost = 0.3640
# Iter 98175 : training cost = 0.3640
# Iter 98180 : training cost = 0.3640
# Iter 98185 : training cost = 0.3640
# Iter 98190 : training cost = 0.3640
# Iter 98195 : training cost = 0.3640
# Iter 98200 : training cost = 0.3640
# Iter 98205 : training cost = 0.3640
# Iter 98210 : training cost = 0.3640
# Iter 98215 : training cost = 0.3640
# Iter 98220 : training cost = 0.3640
# Iter 98225 : training cost = 0.3640
# Iter 98230 : training cost = 0.3640
# Iter 98235 : training cost = 0.3640
# Iter 98240 : training cost = 0.3640
# Iter 98245 : training cost = 0.3640
# Iter 98250 : training cost = 0.3640
# Iter 98255 : training cost = 0.3640
# Iter 98260 : training cost = 0.3640
# Iter 98265 : training cost = 0.3640
# Iter 98270 : training cost = 0.3640
# Iter 98275 : training cost = 0.3640
# Iter 98280 : training cost = 0.3640
# Iter 98285 : training cost = 0.3640
# Iter 98290 : training cost = 0.3640
# Iter 98295 : training cost = 0.3640
# Iter 98300 : training cost = 0.3640
# Iter 98305 : training cost = 0.3640
# Iter 98310 : training cost = 0.3640
# Iter 98315 : training cost = 0.3640
# Iter 98320 : training cost = 0.3640
# Iter 98325 : training cost = 0.3640
# Iter 98330 : training cost = 0.3640
# Iter 98335 : training cost = 0.3640
# Iter 98340 : training cost = 0.3640
# Iter 98345 : training cost = 0.3640
# Iter 98350 : training cost = 0.3640
# Iter 98355 : training cost = 0.3640
# Iter 98360 : training cost = 0.3640
# Iter 98365 : training cost = 0.3640
# Iter 98370 : training cost = 0.3640
# Iter 98375 : training cost = 0.3640
# Iter 98380 : training cost = 0.3640
# Iter 98385 : training cost = 0.3640
# Iter 98390 : training cost = 0.3640
# Iter 98395 : training cost = 0.3640
# Iter 98400 : training cost = 0.3640
# Iter 98405 : training cost = 0.3640
# Iter 98410 : training cost = 0.3640
# Iter 98415 : training cost = 0.3640
# Iter 98420 : training cost = 0.3640
# Iter 98425 : training cost = 0.3640
# Iter 98430 : training cost = 0.3640
# Iter 98435 : training cost = 0.3640
# Iter 98440 : training cost = 0.3640
# Iter 98445 : training cost = 0.3640
# Iter 98450 : training cost = 0.3640
# Iter 98455 : training cost = 0.3640
# Iter 98460 : training cost = 0.3640
# Iter 98465 : training cost = 0.3640
# Iter 98470 : training cost = 0.3640
# Iter 98475 : training cost = 0.3640
# Iter 98480 : training cost = 0.3640
# Iter 98485 : training cost = 0.3640
# Iter 98490 : training cost = 0.3640
# Iter 98495 : training cost = 0.3640
# Iter 98500 : training cost = 0.3640
# Iter 98505 : training cost = 0.3640
# Iter 98510 : training cost = 0.3640
# Iter 98515 : training cost = 0.3640
# Iter 98520 : training cost = 0.3640
# Iter 98525 : training cost = 0.3640
# Iter 98530 : training cost = 0.3640
# Iter 98535 : training cost = 0.3640
# Iter 98540 : training cost = 0.3640
# Iter 98545 : training cost = 0.3640
# Iter 98550 : training cost = 0.3640
# Iter 98555 : training cost = 0.3640
# Iter 98560 : training cost = 0.3640
# Iter 98565 : training cost = 0.3640
# Iter 98570 : training cost = 0.3640
# Iter 98575 : training cost = 0.3640
# Iter 98580 : training cost = 0.3640
# Iter 98585 : training cost = 0.3640
# Iter 98590 : training cost = 0.3640
# Iter 98595 : training cost = 0.3640
# Iter 98600 : training cost = 0.3640
# Iter 98605 : training cost = 0.3640
# Iter 98610 : training cost = 0.3640
# Iter 98615 : training cost = 0.3640
# Iter 98620 : training cost = 0.3640
# Iter 98625 : training cost = 0.3640
# Iter 98630 : training cost = 0.3640
# Iter 98635 : training cost = 0.3640
# Iter 98640 : training cost = 0.3640
# Iter 98645 : training cost = 0.3640
# Iter 98650 : training cost = 0.3640
# Iter 98655 : training cost = 0.3640
# Iter 98660 : training cost = 0.3640
# Iter 98665 : training cost = 0.3640
# Iter 98670 : training cost = 0.3640
# Iter 98675 : training cost = 0.3640
# Iter 98680 : training cost = 0.3640
# Iter 98685 : training cost = 0.3640
# Iter 98690 : training cost = 0.3640
# Iter 98695 : training cost = 0.3640
# Iter 98700 : training cost = 0.3640
# Iter 98705 : training cost = 0.3640
# Iter 98710 : training cost = 0.3640
# Iter 98715 : training cost = 0.3640
# Iter 98720 : training cost = 0.3640
# Iter 98725 : training cost = 0.3640
# Iter 98730 : training cost = 0.3640
# Iter 98735 : training cost = 0.3640
# Iter 98740 : training cost = 0.3640
# Iter 98745 : training cost = 0.3640
# Iter 98750 : training cost = 0.3640
# Iter 98755 : training cost = 0.3640
# Iter 98760 : training cost = 0.3640
# Iter 98765 : training cost = 0.3640
# Iter 98770 : training cost = 0.3640
# Iter 98775 : training cost = 0.3640
# Iter 98780 : training cost = 0.3640
# Iter 98785 : training cost = 0.3640
# Iter 98790 : training cost = 0.3640
# Iter 98795 : training cost = 0.3640
# Iter 98800 : training cost = 0.3640
# Iter 98805 : training cost = 0.3640
# Iter 98810 : training cost = 0.3640
# Iter 98815 : training cost = 0.3640
# Iter 98820 : training cost = 0.3640
# Iter 98825 : training cost = 0.3640
# Iter 98830 : training cost = 0.3640
# Iter 98835 : training cost = 0.3640
# Iter 98840 : training cost = 0.3640
# Iter 98845 : training cost = 0.3640
# Iter 98850 : training cost = 0.3640
# Iter 98855 : training cost = 0.3640
# Iter 98860 : training cost = 0.3640
# Iter 98865 : training cost = 0.3640
# Iter 98870 : training cost = 0.3640
# Iter 98875 : training cost = 0.3640
# Iter 98880 : training cost = 0.3640
# Iter 98885 : training cost = 0.3640
# Iter 98890 : training cost = 0.3640
# Iter 98895 : training cost = 0.3640
# Iter 98900 : training cost = 0.3640
# Iter 98905 : training cost = 0.3640
# Iter 98910 : training cost = 0.3640
# Iter 98915 : training cost = 0.3640
# Iter 98920 : training cost = 0.3640
# Iter 98925 : training cost = 0.3640
# Iter 98930 : training cost = 0.3640
# Iter 98935 : training cost = 0.3640
# Iter 98940 : training cost = 0.3640
# Iter 98945 : training cost = 0.3640
# Iter 98950 : training cost = 0.3640
# Iter 98955 : training cost = 0.3640
# Iter 98960 : training cost = 0.3640
# Iter 98965 : training cost = 0.3640
# Iter 98970 : training cost = 0.3640
# Iter 98975 : training cost = 0.3640
# Iter 98980 : training cost = 0.3640
# Iter 98985 : training cost = 0.3640
# Iter 98990 : training cost = 0.3640
# Iter 98995 : training cost = 0.3640
# Iter 99000 : training cost = 0.3640
# Iter 99005 : training cost = 0.3640
# Iter 99010 : training cost = 0.3640
# Iter 99015 : training cost = 0.3640
# Iter 99020 : training cost = 0.3640
# Iter 99025 : training cost = 0.3640
# Iter 99030 : training cost = 0.3640
# Iter 99035 : training cost = 0.3640
# Iter 99040 : training cost = 0.3640
# Iter 99045 : training cost = 0.3640
# Iter 99050 : training cost = 0.3640
# Iter 99055 : training cost = 0.3640
# Iter 99060 : training cost = 0.3640
# Iter 99065 : training cost = 0.3640
# Iter 99070 : training cost = 0.3640
# Iter 99075 : training cost = 0.3640
# Iter 99080 : training cost = 0.3640
# Iter 99085 : training cost = 0.3640
# Iter 99090 : training cost = 0.3640
# Iter 99095 : training cost = 0.3640
# Iter 99100 : training cost = 0.3640
# Iter 99105 : training cost = 0.3640
# Iter 99110 : training cost = 0.3640
# Iter 99115 : training cost = 0.3640
# Iter 99120 : training cost = 0.3640
# Iter 99125 : training cost = 0.3640
# Iter 99130 : training cost = 0.3640
# Iter 99135 : training cost = 0.3640
# Iter 99140 : training cost = 0.3640
# Iter 99145 : training cost = 0.3640
# Iter 99150 : training cost = 0.3640
# Iter 99155 : training cost = 0.3640
# Iter 99160 : training cost = 0.3640
# Iter 99165 : training cost = 0.3640
# Iter 99170 : training cost = 0.3640
# Iter 99175 : training cost = 0.3640
# Iter 99180 : training cost = 0.3640
# Iter 99185 : training cost = 0.3640
# Iter 99190 : training cost = 0.3640
# Iter 99195 : training cost = 0.3640
# Iter 99200 : training cost = 0.3640
# Iter 99205 : training cost = 0.3640
# Iter 99210 : training cost = 0.3640
# Iter 99215 : training cost = 0.3640
# Iter 99220 : training cost = 0.3640
# Iter 99225 : training cost = 0.3640
# Iter 99230 : training cost = 0.3640
# Iter 99235 : training cost = 0.3640
# Iter 99240 : training cost = 0.3640
# Iter 99245 : training cost = 0.3640
# Iter 99250 : training cost = 0.3640
# Iter 99255 : training cost = 0.3640
# Iter 99260 : training cost = 0.3640
# Iter 99265 : training cost = 0.3640
# Iter 99270 : training cost = 0.3640
# Iter 99275 : training cost = 0.3640
# Iter 99280 : training cost = 0.3640
# Iter 99285 : training cost = 0.3639
# Iter 99290 : training cost = 0.3639
# Iter 99295 : training cost = 0.3639
# Iter 99300 : training cost = 0.3639
# Iter 99305 : training cost = 0.3639
# Iter 99310 : training cost = 0.3639
# Iter 99315 : training cost = 0.3639
# Iter 99320 : training cost = 0.3639
# Iter 99325 : training cost = 0.3639
# Iter 99330 : training cost = 0.3639
# Iter 99335 : training cost = 0.3639
# Iter 99340 : training cost = 0.3639
# Iter 99345 : training cost = 0.3639
# Iter 99350 : training cost = 0.3639
# Iter 99355 : training cost = 0.3639
# Iter 99360 : training cost = 0.3639
# Iter 99365 : training cost = 0.3639
# Iter 99370 : training cost = 0.3639
# Iter 99375 : training cost = 0.3639
# Iter 99380 : training cost = 0.3639
# Iter 99385 : training cost = 0.3639
# Iter 99390 : training cost = 0.3639
# Iter 99395 : training cost = 0.3639
# Iter 99400 : training cost = 0.3639
# Iter 99405 : training cost = 0.3639
# Iter 99410 : training cost = 0.3639
# Iter 99415 : training cost = 0.3639
# Iter 99420 : training cost = 0.3639
# Iter 99425 : training cost = 0.3639
# Iter 99430 : training cost = 0.3639
# Iter 99435 : training cost = 0.3639
# Iter 99440 : training cost = 0.3639
# Iter 99445 : training cost = 0.3639
# Iter 99450 : training cost = 0.3639
# Iter 99455 : training cost = 0.3639
# Iter 99460 : training cost = 0.3639
# Iter 99465 : training cost = 0.3639
# Iter 99470 : training cost = 0.3639
# Iter 99475 : training cost = 0.3639
# Iter 99480 : training cost = 0.3639
# Iter 99485 : training cost = 0.3639
# Iter 99490 : training cost = 0.3639
# Iter 99495 : training cost = 0.3639
# Iter 99500 : training cost = 0.3639
# Iter 99505 : training cost = 0.3639
# Iter 99510 : training cost = 0.3639
# Iter 99515 : training cost = 0.3639
# Iter 99520 : training cost = 0.3639
# Iter 99525 : training cost = 0.3639
# Iter 99530 : training cost = 0.3639
# Iter 99535 : training cost = 0.3639
# Iter 99540 : training cost = 0.3639
# Iter 99545 : training cost = 0.3639
# Iter 99550 : training cost = 0.3639
# Iter 99555 : training cost = 0.3639
# Iter 99560 : training cost = 0.3639
# Iter 99565 : training cost = 0.3639
# Iter 99570 : training cost = 0.3639
# Iter 99575 : training cost = 0.3639
# Iter 99580 : training cost = 0.3639
# Iter 99585 : training cost = 0.3639
# Iter 99590 : training cost = 0.3639
# Iter 99595 : training cost = 0.3639
# Iter 99600 : training cost = 0.3639
# Iter 99605 : training cost = 0.3639
# Iter 99610 : training cost = 0.3639
# Iter 99615 : training cost = 0.3639
# Iter 99620 : training cost = 0.3639
# Iter 99625 : training cost = 0.3639
# Iter 99630 : training cost = 0.3639
# Iter 99635 : training cost = 0.3639
# Iter 99640 : training cost = 0.3639
# Iter 99645 : training cost = 0.3639
# Iter 99650 : training cost = 0.3639
# Iter 99655 : training cost = 0.3639
# Iter 99660 : training cost = 0.3639
# Iter 99665 : training cost = 0.3639
# Iter 99670 : training cost = 0.3639
# Iter 99675 : training cost = 0.3639
# Iter 99680 : training cost = 0.3639
# Iter 99685 : training cost = 0.3639
# Iter 99690 : training cost = 0.3639
# Iter 99695 : training cost = 0.3639
# Iter 99700 : training cost = 0.3639
# Iter 99705 : training cost = 0.3639
# Iter 99710 : training cost = 0.3639
# Iter 99715 : training cost = 0.3639
# Iter 99720 : training cost = 0.3639
# Iter 99725 : training cost = 0.3639
# Iter 99730 : training cost = 0.3639
# Iter 99735 : training cost = 0.3639
# Iter 99740 : training cost = 0.3639
# Iter 99745 : training cost = 0.3639
# Iter 99750 : training cost = 0.3639
# Iter 99755 : training cost = 0.3639
# Iter 99760 : training cost = 0.3639
# Iter 99765 : training cost = 0.3639
# Iter 99770 : training cost = 0.3639
# Iter 99775 : training cost = 0.3639
# Iter 99780 : training cost = 0.3639
# Iter 99785 : training cost = 0.3639
# Iter 99790 : training cost = 0.3639
# Iter 99795 : training cost = 0.3639
# Iter 99800 : training cost = 0.3639
# Iter 99805 : training cost = 0.3639
# Iter 99810 : training cost = 0.3639
# Iter 99815 : training cost = 0.3639
# Iter 99820 : training cost = 0.3639
# Iter 99825 : training cost = 0.3639
# Iter 99830 : training cost = 0.3639
# Iter 99835 : training cost = 0.3639
# Iter 99840 : training cost = 0.3639
# Iter 99845 : training cost = 0.3639
# Iter 99850 : training cost = 0.3639
# Iter 99855 : training cost = 0.3639
# Iter 99860 : training cost = 0.3639
# Iter 99865 : training cost = 0.3639
# Iter 99870 : training cost = 0.3639
# Iter 99875 : training cost = 0.3639
# Iter 99880 : training cost = 0.3639
# Iter 99885 : training cost = 0.3639
# Iter 99890 : training cost = 0.3639
# Iter 99895 : training cost = 0.3639
# Iter 99900 : training cost = 0.3639
# Iter 99905 : training cost = 0.3639
# Iter 99910 : training cost = 0.3639
# Iter 99915 : training cost = 0.3639
# Iter 99920 : training cost = 0.3639
# Iter 99925 : training cost = 0.3639
# Iter 99930 : training cost = 0.3639
# Iter 99935 : training cost = 0.3639
# Iter 99940 : training cost = 0.3639
# Iter 99945 : training cost = 0.3639
# Iter 99950 : training cost = 0.3639
# Iter 99955 : training cost = 0.3639
# Iter 99960 : training cost = 0.3639
# Iter 99965 : training cost = 0.3639
# Iter 99970 : training cost = 0.3639
# Iter 99975 : training cost = 0.3639
# Iter 99980 : training cost = 0.3639
# Iter 99985 : training cost = 0.3639
# Iter 99990 : training cost = 0.3639
# Iter 99995 : training cost = 0.3639
# Iter 100000 : training cost = 0.3639

# %%
def plot_history_cost(history):
    plt.plot(history['iter'], history['cost'], label='cost')
    plt.ylabel('Cost', fontsize=13)
    plt.xlabel('Iterations', fontsize=13)
    plt.title('Cost vs iterations', fontsize=18)
    plt.show()

plot_history_cost(history)

# %% [markdown]
# > **Task 4.2 (8 marks)** Evaluate the trained model
# >
# > Complete the function `a1_mlp.evaluate` which uses the trained model to evaluate on the validation set `X_val`, `y_val`.
# > The model parameters is stored in (`weights` and `biases`) and the activation functions used are stored in `act_functions`.
# > The predicted label is acquired through thresholding:
# > $$ \mathbf{y}_{\mathrm{pred}} =
#   \begin{cases}
#     1 & \text{if } \hat{\mathbf{y}} \geq 0.5\\
#     0 & \text{otherwise}\\
#   \end{cases}$$
# > The compare the predicted label against the actual label `y_val`.

# %%
reload(a1_mlp)

y_hat, y_pred, acc = a1_mlp.evaluate(X_val, y_val, weights, biases, act_functions)
print(f'Validation accuracy = {acc:.4f}')
# Out:
# Validation accuracy = 0.8852

# %% [markdown]
# <center> --- END OF ASSESSMENT --- </center>
